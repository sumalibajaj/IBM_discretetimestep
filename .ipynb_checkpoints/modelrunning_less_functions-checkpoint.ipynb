# %%
# Importing  all the functions defined in functions.py
from functions_less_functions import *

# %%
# from numpy import * 

# model setup
n_iter = 1
t_max = 150 # how many days will the simulation run
n_hh = 100
type_of_hh_array = [0, 1, 2]
prob_type_of_hh_array = [0.33, 0.33, 0.34]
mean_hh_size_array = [5, 5, 5]
initial_prob_I_array = [0.01, 0.01, 0.01]
mean_n_contacts_outside_hh = np.array([[3, 4, 2], [2, 3, 2], [2, 2, 3]])

# transmission parameters
max_recovery_t = 10 # assuming person definitely recovers by these many days
p_max = 0.02 # probability of infecting someone upon contact on most infectious day
mean_gamma = 3.86
sd_gamma = 2.65

# %%
# calculating probability of infecting someone upon contact given the no. of days since infection.
p_t = cal_prob_of_inf(p_max, mean_gamma, sd_gamma, t_inf_max = max_recovery_t)

#define x-axis values
t = np.linspace (0, max_recovery_t, max_recovery_t+1) 

# import matplotlib.pyplot as plt
# #create plot of Gamma distribution
# plt.plot(t, p_t)

# %%
list_hh_ind_input = create_hh(n_hh_input = n_hh, type_of_hh_array_input = type_of_hh_array, \
                              prob_type_of_hh_array_input = prob_type_of_hh_array, \
                              mean_hh_size_array_input = mean_hh_size_array, \
                              initial_prob_I_array_input = initial_prob_I_array)

n_ind_input = len(list_hh_ind_input[1])

# %%
print("no. of inds in area 0 ", len(list_hh_ind_input[2][0]))
print("no. of inds in area 1 ", len(list_hh_ind_input[2][1]))
print("no. of inds in area 2 ", len(list_hh_ind_input[2][2]))
# Out:
# no. of inds in area 0  185
# no. of inds in area 1  125
# no. of inds in area 2  172

# %%
import networkx as nx
import matplotlib as plt

# creating connections between members of the same household
# initialising graph
graph = nx.Graph()

for hh in range(n_hh):
    inds_temp = list_hh_ind_input[0][hh].get_individuals()
    graph.add_nodes_from(inds_temp)
    graph.add_edges_from(itertools.combinations(inds_temp, 2))
    

# ADD THIS TO CREATING INDIVIDUALS FUNCTION
# Adding attributes about how many contacts will people have within and outside their area
for ind in list_hh_ind_input[1]:
    area_temp = ind.get_type_of_hh()    
    temp_within_area_contacts = np.random.poisson(mean_n_contacts_outside_hh[area_temp][area_temp], 1)[0]
    ind.add_n_within_area_contacts(temp_within_area_contacts)
    

# creating connections between members of the same area   
for area in range(len(type_of_hh_array)):
# for area in range(1):    
    ind_tick = 0
    list_inds_available = list_hh_ind_input[2][area]
    for ind1 in list_hh_ind_input[2][area]:   
        # choosing ind1 from the list of individuals in a given area
        ind1_degree_hh = ind1.get_hh_size() - 1 # this is fixed number for an individual
        ind1_degree_hh_within_area = ind1_degree_hh + ind1.get_n_within_area_contacts() # this is fixed number for an individual

        # check if any individuals are available to be connected to
        if len(list_inds_available) == 0:
            # forcing ind1's within area contacts = 0 if no individual is left
            ind1.add_n_within_area_contacts(0) # BEST THING TO DO?
            
        else:
            # don't run the following if the maximum possible connections for ind1 has been reached
            while graph.degree[ind1] < ind1_degree_hh_within_area:    
                # drawing a potential contact from within the area
                # if there are available individuals, continue and draw one randomly
                if len(list_inds_available) != 0:
                    ind2  = random.sample(list_inds_available, 1)[0]           
                    # checking how many contacts this person can have (in hh and within area)
                    ind2_degree_hh = ind2.get_hh_size() - 1
                    ind2_degree_hh_within_area = ind2_degree_hh + ind2.get_n_within_area_contacts()

                    # check if this person is from same hh, or already connected, or has reached maximum possible connections setup                
                    if (ind2.get_hh() == ind1.get_hh()) | (ind2 in graph[ind1]) | (graph.degree[ind2] == ind2_degree_hh_within_area):
                        list_inds_available = list(set(list_inds_available) - set([ind2]))
                    else:
                        graph.add_edge(ind1, ind2)
                else:
                    # correct within area contacts to how many were possible
                    ind1.add_n_within_area_contacts(graph.degree[ind1] - (ind1.get_hh_size() - 1)) 
#                     print("breaking from the while loop")
#                     print("setting within area connections for id", ind1.get_ID(), " to ", ind1.get_n_within_area_contacts())
                    break
            # remove ind1 from available list of someone's potential contact within the area (because all of ind1's contacts are exhausted now)
            list_inds_available = list(set(list_inds_available) - set([ind1]))
# Out:
# breaking from the while loop
# setting within area connections for id 470  to  3
# breaking from the while loop
# setting within area connections for id 431  to  4
# breaking from the while loop
# setting within area connections for id 457  to  4

# %%
# for i in list_hh_ind_input[1]:
#     print("id=",i.get_ID(), "area=", i.get_type_of_hh(), "connections=", graph.degree[i])
# Out:
# id= 0 area= 0 connections= 7
# id= 1 area= 0 connections= 9
# id= 2 area= 0 connections= 10
# id= 3 area= 0 connections= 9
# id= 4 area= 0 connections= 8
# id= 5 area= 0 connections= 7
# id= 6 area= 0 connections= 6
# id= 7 area= 0 connections= 7
# id= 8 area= 0 connections= 8
# id= 9 area= 0 connections= 5
# id= 10 area= 0 connections= 6
# id= 11 area= 0 connections= 5
# id= 12 area= 0 connections= 7
# id= 13 area= 0 connections= 6
# id= 14 area= 0 connections= 7
# id= 15 area= 0 connections= 4
# id= 16 area= 0 connections= 7
# id= 17 area= 0 connections= 6
# id= 18 area= 0 connections= 7
# id= 19 area= 0 connections= 10
# id= 20 area= 0 connections= 6
# id= 21 area= 1 connections= 6
# id= 22 area= 1 connections= 5
# id= 23 area= 1 connections= 3
# id= 24 area= 0 connections= 8
# id= 25 area= 0 connections= 8
# id= 26 area= 0 connections= 8
# id= 27 area= 0 connections= 8
# id= 28 area= 0 connections= 9
# id= 29 area= 0 connections= 6
# id= 30 area= 2 connections= 11
# id= 31 area= 2 connections= 7
# id= 32 area= 2 connections= 8
# id= 33 area= 2 connections= 8
# id= 34 area= 2 connections= 10
# id= 35 area= 2 connections= 8
# id= 36 area= 2 connections= 9
# id= 37 area= 2 connections= 7
# id= 38 area= 2 connections= 8
# id= 39 area= 2 connections= 10
# id= 40 area= 2 connections= 9
# id= 41 area= 2 connections= 8
# id= 42 area= 2 connections= 8
# id= 43 area= 2 connections= 9
# id= 44 area= 2 connections= 5
# id= 45 area= 2 connections= 10
# id= 46 area= 2 connections= 7
# id= 47 area= 2 connections= 7
# id= 48 area= 2 connections= 7
# id= 49 area= 2 connections= 6
# id= 50 area= 0 connections= 6
# id= 51 area= 0 connections= 5
# id= 52 area= 1 connections= 4
# id= 53 area= 1 connections= 4
# id= 54 area= 1 connections= 4
# id= 55 area= 0 connections= 9
# id= 56 area= 0 connections= 6
# id= 57 area= 0 connections= 6
# id= 58 area= 0 connections= 4
# id= 59 area= 0 connections= 4
# id= 60 area= 0 connections= 5
# id= 61 area= 0 connections= 3
# id= 62 area= 0 connections= 7
# id= 63 area= 0 connections= 4
# id= 64 area= 2 connections= 8
# id= 65 area= 2 connections= 6
# id= 66 area= 2 connections= 9
# id= 67 area= 2 connections= 10
# id= 68 area= 2 connections= 7
# id= 69 area= 2 connections= 9
# id= 70 area= 2 connections= 7
# id= 71 area= 2 connections= 8
# id= 72 area= 2 connections= 6
# id= 73 area= 2 connections= 8
# id= 74 area= 2 connections= 5
# id= 75 area= 2 connections= 10
# id= 76 area= 2 connections= 12
# id= 77 area= 2 connections= 11
# id= 78 area= 2 connections= 13
# id= 79 area= 2 connections= 11
# id= 80 area= 2 connections= 12
# id= 81 area= 2 connections= 10
# id= 82 area= 2 connections= 15
# id= 83 area= 2 connections= 13
# id= 84 area= 2 connections= 10
# id= 85 area= 1 connections= 4
# id= 86 area= 1 connections= 7
# id= 87 area= 1 connections= 6
# id= 88 area= 1 connections= 6
# id= 89 area= 1 connections= 5
# id= 90 area= 0 connections= 9
# id= 91 area= 0 connections= 7
# id= 92 area= 0 connections= 9
# id= 93 area= 0 connections= 10
# id= 94 area= 0 connections= 8
# id= 95 area= 0 connections= 10
# id= 96 area= 0 connections= 8
# id= 97 area= 2 connections= 3
# id= 98 area= 0 connections= 9
# id= 99 area= 0 connections= 8
# id= 100 area= 0 connections= 10
# id= 101 area= 0 connections= 6
# id= 102 area= 0 connections= 10
# id= 103 area= 0 connections= 8
# id= 104 area= 0 connections= 6
# id= 105 area= 2 connections= 8
# id= 106 area= 2 connections= 7
# id= 107 area= 2 connections= 6
# id= 108 area= 2 connections= 9
# id= 109 area= 2 connections= 4
# id= 110 area= 1 connections= 7
# id= 111 area= 1 connections= 6
# id= 112 area= 1 connections= 6
# id= 113 area= 1 connections= 7
# id= 114 area= 1 connections= 4
# id= 115 area= 1 connections= 6
# id= 116 area= 1 connections= 8
# id= 117 area= 1 connections= 7
# id= 118 area= 0 connections= 10
# id= 119 area= 0 connections= 6
# id= 120 area= 0 connections= 8
# id= 121 area= 0 connections= 7
# id= 122 area= 0 connections= 9
# id= 123 area= 0 connections= 9
# id= 124 area= 1 connections= 2
# id= 125 area= 1 connections= 4
# id= 126 area= 1 connections= 8
# id= 127 area= 1 connections= 7
# id= 128 area= 1 connections= 5
# id= 129 area= 1 connections= 6
# id= 130 area= 1 connections= 6
# id= 131 area= 2 connections= 8
# id= 132 area= 2 connections= 8
# id= 133 area= 2 connections= 8
# id= 134 area= 2 connections= 10
# id= 135 area= 2 connections= 8
# id= 136 area= 2 connections= 9
# id= 137 area= 2 connections= 11
# id= 138 area= 2 connections= 12
# id= 139 area= 0 connections= 5
# id= 140 area= 0 connections= 6
# id= 141 area= 2 connections= 4
# id= 142 area= 2 connections= 8
# id= 143 area= 2 connections= 5
# id= 144 area= 1 connections= 8
# id= 145 area= 1 connections= 7
# id= 146 area= 1 connections= 9
# id= 147 area= 1 connections= 11
# id= 148 area= 1 connections= 7
# id= 149 area= 1 connections= 9
# id= 150 area= 1 connections= 8
# id= 151 area= 2 connections= 5
# id= 152 area= 2 connections= 4
# id= 153 area= 2 connections= 7
# id= 154 area= 2 connections= 14
# id= 155 area= 0 connections= 10
# id= 156 area= 0 connections= 7
# id= 157 area= 0 connections= 10
# id= 158 area= 0 connections= 7
# id= 159 area= 0 connections= 9
# id= 160 area= 0 connections= 12
# id= 161 area= 0 connections= 12
# id= 162 area= 0 connections= 8
# id= 163 area= 0 connections= 5
# id= 164 area= 0 connections= 8
# id= 165 area= 0 connections= 8
# id= 166 area= 0 connections= 12
# id= 167 area= 2 connections= 5
# id= 168 area= 2 connections= 5
# id= 169 area= 2 connections= 4
# id= 170 area= 2 connections= 5
# id= 171 area= 2 connections= 5
# id= 172 area= 2 connections= 5
# id= 173 area= 2 connections= 6
# id= 174 area= 2 connections= 9
# id= 175 area= 2 connections= 7
# id= 176 area= 1 connections= 5
# id= 177 area= 1 connections= 7
# id= 178 area= 1 connections= 7
# id= 179 area= 1 connections= 6
# id= 180 area= 1 connections= 5
# id= 181 area= 2 connections= 5
# id= 182 area= 2 connections= 7
# id= 183 area= 2 connections= 7
# id= 184 area= 2 connections= 10
# id= 185 area= 2 connections= 9
# id= 186 area= 2 connections= 7
# id= 187 area= 2 connections= 3
# id= 188 area= 2 connections= 6
# id= 189 area= 2 connections= 5
# id= 190 area= 0 connections= 5
# id= 191 area= 0 connections= 5
# id= 192 area= 0 connections= 2
# id= 193 area= 2 connections= 5
# id= 194 area= 2 connections= 6
# id= 195 area= 2 connections= 6
# id= 196 area= 2 connections= 11
# id= 197 area= 2 connections= 6
# id= 198 area= 1 connections= 9
# id= 199 area= 1 connections= 4
# id= 200 area= 1 connections= 4
# id= 201 area= 1 connections= 5
# id= 202 area= 1 connections= 2
# id= 203 area= 2 connections= 4
# id= 204 area= 2 connections= 3
# id= 205 area= 0 connections= 7
# id= 206 area= 0 connections= 9
# id= 207 area= 0 connections= 11
# id= 208 area= 0 connections= 8
# id= 209 area= 0 connections= 7
# id= 210 area= 0 connections= 7
# id= 211 area= 0 connections= 7
# id= 212 area= 0 connections= 11
# id= 213 area= 0 connections= 12
# id= 214 area= 0 connections= 10
# id= 215 area= 0 connections= 10
# id= 216 area= 0 connections= 9
# id= 217 area= 2 connections= 7
# id= 218 area= 2 connections= 5
# id= 219 area= 2 connections= 4
# id= 220 area= 2 connections= 4
# id= 221 area= 2 connections= 2
# id= 222 area= 2 connections= 4
# id= 223 area= 2 connections= 9
# id= 224 area= 2 connections= 9
# id= 225 area= 2 connections= 8
# id= 226 area= 2 connections= 15
# id= 227 area= 2 connections= 9
# id= 228 area= 2 connections= 12
# id= 229 area= 2 connections= 12
# id= 230 area= 2 connections= 9
# id= 231 area= 0 connections= 6
# id= 232 area= 0 connections= 5
# id= 233 area= 0 connections= 5
# id= 234 area= 1 connections= 6
# id= 235 area= 1 connections= 7
# id= 236 area= 1 connections= 4
# id= 237 area= 1 connections= 9
# id= 238 area= 1 connections= 8
# id= 239 area= 0 connections= 3
# id= 240 area= 0 connections= 2
# id= 241 area= 2 connections= 7
# id= 242 area= 2 connections= 9
# id= 243 area= 2 connections= 4
# id= 244 area= 2 connections= 11
# id= 245 area= 0 connections= 3
# id= 246 area= 0 connections= 10
# id= 247 area= 1 connections= 9
# id= 248 area= 1 connections= 8
# id= 249 area= 1 connections= 10
# id= 250 area= 1 connections= 8
# id= 251 area= 1 connections= 8
# id= 252 area= 1 connections= 10
# id= 253 area= 1 connections= 9
# id= 254 area= 0 connections= 9
# id= 255 area= 0 connections= 5
# id= 256 area= 0 connections= 6
# id= 257 area= 0 connections= 6
# id= 258 area= 2 connections= 3
# id= 259 area= 1 connections= 11
# id= 260 area= 1 connections= 7
# id= 261 area= 1 connections= 8
# id= 262 area= 1 connections= 7
# id= 263 area= 1 connections= 12
# id= 264 area= 1 connections= 8
# id= 265 area= 0 connections= 9
# id= 266 area= 0 connections= 8
# id= 267 area= 0 connections= 6
# id= 268 area= 0 connections= 9
# id= 269 area= 0 connections= 8
# id= 270 area= 0 connections= 12
# id= 271 area= 1 connections= 11
# id= 272 area= 1 connections= 9
# id= 273 area= 1 connections= 9
# id= 274 area= 1 connections= 8
# id= 275 area= 1 connections= 9
# id= 276 area= 1 connections= 7
# id= 277 area= 1 connections= 8
# id= 278 area= 2 connections= 8
# id= 279 area= 2 connections= 8
# id= 280 area= 2 connections= 5
# id= 281 area= 2 connections= 5
# id= 282 area= 2 connections= 10
# id= 283 area= 1 connections= 8
# id= 284 area= 1 connections= 4
# id= 285 area= 1 connections= 5
# id= 286 area= 1 connections= 5
# id= 287 area= 2 connections= 7
# id= 288 area= 2 connections= 11
# id= 289 area= 2 connections= 10
# id= 290 area= 2 connections= 4
# id= 291 area= 2 connections= 8
# id= 292 area= 1 connections= 8
# id= 293 area= 1 connections= 10
# id= 294 area= 1 connections= 6
# id= 295 area= 1 connections= 8
# id= 296 area= 1 connections= 11
# id= 297 area= 1 connections= 8
# id= 298 area= 0 connections= 13
# id= 299 area= 0 connections= 11
# id= 300 area= 0 connections= 8
# id= 301 area= 0 connections= 9
# id= 302 area= 0 connections= 10
# id= 303 area= 0 connections= 12
# id= 304 area= 0 connections= 7
# id= 305 area= 0 connections= 9
# id= 306 area= 2 connections= 8
# id= 307 area= 2 connections= 9
# id= 308 area= 2 connections= 8
# id= 309 area= 2 connections= 7
# id= 310 area= 2 connections= 9
# id= 311 area= 2 connections= 6
# id= 312 area= 2 connections= 7
# id= 313 area= 2 connections= 6
# id= 314 area= 2 connections= 5
# id= 315 area= 0 connections= 10
# id= 316 area= 0 connections= 9
# id= 317 area= 0 connections= 8
# id= 318 area= 0 connections= 10
# id= 319 area= 0 connections= 9
# id= 320 area= 0 connections= 7
# id= 321 area= 0 connections= 8
# id= 322 area= 1 connections= 9
# id= 323 area= 1 connections= 6
# id= 324 area= 1 connections= 7
# id= 325 area= 1 connections= 12
# id= 326 area= 1 connections= 6
# id= 327 area= 1 connections= 9
# id= 328 area= 1 connections= 10
# id= 329 area= 0 connections= 6
# id= 330 area= 0 connections= 5
# id= 331 area= 0 connections= 6
# id= 332 area= 0 connections= 6
# id= 333 area= 0 connections= 8
# id= 334 area= 1 connections= 5
# id= 335 area= 1 connections= 4
# id= 336 area= 1 connections= 6
# id= 337 area= 1 connections= 4
# id= 338 area= 2 connections= 10
# id= 339 area= 2 connections= 8
# id= 340 area= 2 connections= 8
# id= 341 area= 2 connections= 10
# id= 342 area= 2 connections= 10
# id= 343 area= 2 connections= 12
# id= 344 area= 2 connections= 7
# id= 345 area= 0 connections= 9
# id= 346 area= 0 connections= 5
# id= 347 area= 0 connections= 6
# id= 348 area= 0 connections= 9
# id= 349 area= 0 connections= 5
# id= 350 area= 0 connections= 9
# id= 351 area= 2 connections= 9
# id= 352 area= 2 connections= 8
# id= 353 area= 2 connections= 12
# id= 354 area= 2 connections= 9
# id= 355 area= 2 connections= 10
# id= 356 area= 2 connections= 8
# id= 357 area= 2 connections= 9
# id= 358 area= 0 connections= 4
# id= 359 area= 0 connections= 6
# id= 360 area= 0 connections= 6
# id= 361 area= 2 connections= 7
# id= 362 area= 2 connections= 5
# id= 363 area= 2 connections= 7
# id= 364 area= 2 connections= 6
# id= 365 area= 2 connections= 7
# id= 366 area= 1 connections= 4
# id= 367 area= 1 connections= 6
# id= 368 area= 1 connections= 4
# id= 369 area= 1 connections= 5
# id= 370 area= 2 connections= 3
# id= 371 area= 2 connections= 5
# id= 372 area= 2 connections= 4
# id= 373 area= 2 connections= 6
# id= 374 area= 2 connections= 5
# id= 375 area= 2 connections= 4
# id= 376 area= 2 connections= 5
# id= 377 area= 2 connections= 7
# id= 378 area= 2 connections= 7
# id= 379 area= 2 connections= 8
# id= 380 area= 2 connections= 11
# id= 381 area= 2 connections= 6
# id= 382 area= 2 connections= 5
# id= 383 area= 2 connections= 3
# id= 384 area= 0 connections= 7
# id= 385 area= 0 connections= 6
# id= 386 area= 0 connections= 7
# id= 387 area= 0 connections= 7
# id= 388 area= 0 connections= 7
# id= 389 area= 0 connections= 8
# id= 390 area= 1 connections= 7
# id= 391 area= 1 connections= 5
# id= 392 area= 1 connections= 7
# id= 393 area= 1 connections= 12
# id= 394 area= 1 connections= 7
# id= 395 area= 0 connections= 10
# id= 396 area= 0 connections= 12
# id= 397 area= 0 connections= 8
# id= 398 area= 0 connections= 8
# id= 399 area= 0 connections= 10
# id= 400 area= 0 connections= 8
# id= 401 area= 0 connections= 12
# id= 402 area= 0 connections= 8
# id= 403 area= 1 connections= 8
# id= 404 area= 1 connections= 8
# id= 405 area= 1 connections= 5
# id= 406 area= 1 connections= 6
# id= 407 area= 1 connections= 5
# id= 408 area= 0 connections= 8
# id= 409 area= 0 connections= 6
# id= 410 area= 0 connections= 7
# id= 411 area= 0 connections= 8
# id= 412 area= 0 connections= 10
# id= 413 area= 2 connections= 4
# id= 414 area= 2 connections= 3
# id= 415 area= 1 connections= 7
# id= 416 area= 1 connections= 3
# id= 417 area= 1 connections= 2
# id= 418 area= 0 connections= 12
# id= 419 area= 0 connections= 8
# id= 420 area= 0 connections= 9
# id= 421 area= 0 connections= 10
# id= 422 area= 0 connections= 11
# id= 423 area= 0 connections= 10
# id= 424 area= 0 connections= 10
# id= 425 area= 0 connections= 13
# id= 426 area= 1 connections= 5
# id= 427 area= 1 connections= 4
# id= 428 area= 1 connections= 7
# id= 429 area= 1 connections= 5
# id= 430 area= 1 connections= 7
# id= 431 area= 1 connections= 8
# id= 432 area= 1 connections= 6
# id= 433 area= 1 connections= 8
# id= 434 area= 1 connections= 10
# id= 435 area= 1 connections= 12
# id= 436 area= 1 connections= 8
# id= 437 area= 1 connections= 9
# id= 438 area= 1 connections= 9
# id= 439 area= 1 connections= 11
# id= 440 area= 1 connections= 11
# id= 441 area= 2 connections= 5
# id= 442 area= 2 connections= 10
# id= 443 area= 2 connections= 4
# id= 444 area= 2 connections= 4
# id= 445 area= 0 connections= 8
# id= 446 area= 0 connections= 8
# id= 447 area= 0 connections= 9
# id= 448 area= 0 connections= 6
# id= 449 area= 0 connections= 9
# id= 450 area= 0 connections= 8
# id= 451 area= 0 connections= 9
# id= 452 area= 0 connections= 5
# id= 453 area= 0 connections= 6
# id= 454 area= 0 connections= 9
# id= 455 area= 0 connections= 7
# id= 456 area= 0 connections= 9
# id= 457 area= 2 connections= 11
# id= 458 area= 2 connections= 13
# id= 459 area= 2 connections= 9
# id= 460 area= 2 connections= 8
# id= 461 area= 2 connections= 11
# id= 462 area= 2 connections= 10
# id= 463 area= 2 connections= 15
# id= 464 area= 2 connections= 9
# id= 465 area= 1 connections= 6
# id= 466 area= 1 connections= 5
# id= 467 area= 1 connections= 5
# id= 468 area= 1 connections= 6
# id= 469 area= 0 connections= 5
# id= 470 area= 0 connections= 5
# id= 471 area= 0 connections= 3
# id= 472 area= 0 connections= 12
# id= 473 area= 0 connections= 13
# id= 474 area= 0 connections= 11
# id= 475 area= 0 connections= 12
# id= 476 area= 0 connections= 13
# id= 477 area= 0 connections= 11
# id= 478 area= 0 connections= 10
# id= 479 area= 0 connections= 15
# id= 480 area= 0 connections= 15
# id= 481 area= 0 connections= 9

# %%
# creating connections between members of different areas 
for i in range(len(type_of_hh_array)-1):  

    # finding individuals to connect to in the next areas j
    for j in range(i+1, len(type_of_hh_array)):   
        
        # assigning how many contacts individuals in area i will have with area j
        ig_list1 = [x.add_n_outside_area_temp(np.random.poisson(mean_n_contacts_outside_hh[i][j], 1)) for x in list_hh_ind_input[2][i]]
#         ig_list1 = [x.add_n_outside_area_temp(mean_n_contacts_outside_hh[i][j]) for x in list_hh_ind_input[2][i]]
        
        # create a copy of individuals in area j and later remove individuals who are no longer available to be connected
        list_inds_available = list_hh_ind_input[2][j]
        
        for ind1 in list_hh_ind_input[2][i]:
#             print("")
#             print("finding connections for id", ind1.get_ID(), " of area", i, " in area", j)
            
            # assign how many contacts will individuals (ind2s) in area j have with area i
            ig_list2 = [x.add_n_outside_area_contacts(np.random.poisson(mean_n_contacts_outside_hh[j][i], 1)) for x in list_inds_available]
#             ig_list2 = [x.add_n_outside_area_contacts(mean_n_contacts_outside_hh[j][i]) for x in list_inds_available]

            # calculate how many contacts can ind1 have in area j
#             ind1_degree_hh = ind1.get_hh_size() - 1 # this is fixed number for an individual
#             ind1_degree_hh_within_area = ind1_degree_hh + ind1.get_n_within_area_contacts() # this is fixed number for an individual
            ind1_degree_hh_within_area = graph.degree[ind1]
            ind1_degree_area_i_j = ind1.get_n_outside_area_temp()         
            ind1_degree_hh_within_outside_area_temp = ind1_degree_hh_within_area + ind1_degree_area_i_j # this is fixed number for an individual
#             print("connections needed for id", ind1.get_ID(), "=", ind1_degree_hh_within_outside_area_temp, "and connections acheived=", graph.degree[ind1])

              # check if any individuals are available to be connected to
            if len(list_inds_available) == 0:
                
                # forcing ind1's within area contacts = 0 if no individual is left
                ind1.add_n_outside_area_contacts(0)
#                 print("setting 0 contacts in area", j, " for id", ind1.get_ID())

            else:          
                
                # don't run the following if the maximum possible connections for ind1 has been reached
                while graph.degree[ind1] < ind1_degree_hh_within_outside_area_temp:
#                     print("no. of available ind2s ", len(list_inds_available))
                    
                    # if there are available individuals, continue and draw one randomly
                    if len(list_inds_available) != 0:
                        
                        # drawing a potential contact from outside the area
                        ind2  = random.sample(list_inds_available, 1)[0]
                        # checking how many contacts this person can have (in hh and within area)
                        ind2_degree_hh = ind2.get_hh_size() - 1
                        ind2_degree_hh_within_area = ind2_degree_hh + ind2.get_n_within_area_contacts()
                        ind2_degree_hh_within_outside_area = ind2_degree_hh_within_area + ind2.get_n_outside_area_contacts() # this is fixed number for an individual

                        # check if this person is laready connected to ind1 or has reached maximum possible connections setup                
                        if (ind2 in graph[ind1]) | (graph.degree[ind2] == ind2_degree_hh_within_outside_area):
                            
                            list_inds_available = list(set(list_inds_available) - set([ind2]))
#                             print("Rejecting this id", ind2.get_ID())
                            
                        else:
                            
                            graph.add_edge(ind1, ind2)
#                             print("connected id", ind1.get_ID(), " to id", ind2.get_ID(), " who has", graph.degree[ind2], "connections out of ", ind2_degree_hh_within_outside_area)
                    
#                         print("id", ind1.get_ID(), "now has ", graph.degree[ind1], " contacts") 

                    else:
                        
                        print("breaking from the while loop")
                        break
# Out:
# finding connections for id 0  of area 0  in area 1
# connections needed for id 0 = [12] and connections acheived= 7
# no. of available ind2s  125
# connected id 0  to id 368  who has 5 connections out of  [5]
# id 0 now has  8  contacts
# no. of available ind2s  125
# Rejecting this id 336
# id 0 now has  8  contacts
# no. of available ind2s  124
# connected id 0  to id 324  who has 8 connections out of  [12]
# id 0 now has  9  contacts
# no. of available ind2s  124
# Rejecting this id 369
# id 0 now has  9  contacts
# no. of available ind2s  123
# connected id 0  to id 283  who has 9 connections out of  [10]
# id 0 now has  10  contacts
# no. of available ind2s  123
# connected id 0  to id 238  who has 9 connections out of  [12]
# id 0 now has  11  contacts
# no. of available ind2s  123
# connected id 0  to id 249  who has 11 connections out of  [12]
# id 0 now has  12  contacts
#
# finding connections for id 1  of area 0  in area 1
# connections needed for id 1 = [14] and connections acheived= 9
# no. of available ind2s  123
# connected id 1  to id 296  who has 12 connections out of  [12]
# id 1 now has  10  contacts
# no. of available ind2s  123
# connected id 1  to id 87  who has 7 connections out of  [10]
# id 1 now has  11  contacts
# no. of available ind2s  123
# connected id 1  to id 180  who has 6 connections out of  [8]
# id 1 now has  12  contacts
# no. of available ind2s  123
# connected id 1  to id 250  who has 9 connections out of  [9]
# id 1 now has  13  contacts
# no. of available ind2s  123
# Rejecting this id 274
# id 1 now has  13  contacts
# no. of available ind2s  122
# connected id 1  to id 297  who has 9 connections out of  [11]
# id 1 now has  14  contacts
#
# finding connections for id 2  of area 0  in area 1
# connections needed for id 2 = [15] and connections acheived= 10
# no. of available ind2s  122
# connected id 2  to id 428  who has 8 connections out of  [9]
# id 2 now has  11  contacts
# no. of available ind2s  122
# connected id 2  to id 434  who has 11 connections out of  [9]
# id 2 now has  12  contacts
# no. of available ind2s  122
# Rejecting this id 297
# id 2 now has  12  contacts
# no. of available ind2s  121
# connected id 2  to id 198  who has 10 connections out of  [10]
# id 2 now has  13  contacts
# no. of available ind2s  121
# connected id 2  to id 284  who has 5 connections out of  [5]
# id 2 now has  14  contacts
# no. of available ind2s  121
# connected id 2  to id 238  who has 10 connections out of  [10]
# id 2 now has  15  contacts
#
# finding connections for id 3  of area 0  in area 1
# connections needed for id 3 = [13] and connections acheived= 9
# no. of available ind2s  121
# connected id 3  to id 200  who has 5 connections out of  [7]
# id 3 now has  10  contacts
# no. of available ind2s  121
# connected id 3  to id 394  who has 8 connections out of  [11]
# id 3 now has  11  contacts
# no. of available ind2s  121
# connected id 3  to id 434  who has 12 connections out of  [8]
# id 3 now has  12  contacts
# no. of available ind2s  121
# Rejecting this id 394
# id 3 now has  12  contacts
# no. of available ind2s  120
# connected id 3  to id 202  who has 3 connections out of  [3]
# id 3 now has  13  contacts
#
# finding connections for id 4  of area 0  in area 1
# connections needed for id 4 = [13] and connections acheived= 8
# no. of available ind2s  120
# connected id 4  to id 433  who has 9 connections out of  [10]
# id 4 now has  9  contacts
# no. of available ind2s  120
# connected id 4  to id 438  who has 10 connections out of  [13]
# id 4 now has  10  contacts
# no. of available ind2s  120
# connected id 4  to id 390  who has 8 connections out of  [8]
# id 4 now has  11  contacts
# no. of available ind2s  120
# Rejecting this id 390
# id 4 now has  11  contacts
# no. of available ind2s  119
# connected id 4  to id 248  who has 9 connections out of  [9]
# id 4 now has  12  contacts
# no. of available ind2s  119
# connected id 4  to id 199  who has 5 connections out of  [6]
# id 4 now has  13  contacts
#
# finding connections for id 5  of area 0  in area 1
# connections needed for id 5 = [10] and connections acheived= 7
# no. of available ind2s  119
# connected id 5  to id 416  who has 4 connections out of  [4]
# id 5 now has  8  contacts
# no. of available ind2s  119
# connected id 5  to id 393  who has 13 connections out of  [13]
# id 5 now has  9  contacts
# no. of available ind2s  119
# connected id 5  to id 428  who has 9 connections out of  [9]
# id 5 now has  10  contacts
#
# finding connections for id 6  of area 0  in area 1
# connections needed for id 6 = [14] and connections acheived= 6
# no. of available ind2s  119
# connected id 6  to id 22  who has 6 connections out of  [7]
# id 6 now has  7  contacts
# no. of available ind2s  119
# Rejecting this id 427
# id 6 now has  7  contacts
# no. of available ind2s  118
# connected id 6  to id 126  who has 9 connections out of  [9]
# id 6 now has  8  contacts
# no. of available ind2s  118
# connected id 6  to id 150  who has 9 connections out of  [13]
# id 6 now has  9  contacts
# no. of available ind2s  118
# connected id 6  to id 178  who has 8 connections out of  [8]
# id 6 now has  10  contacts
# no. of available ind2s  118
# connected id 6  to id 124  who has 3 connections out of  [6]
# id 6 now has  11  contacts
# no. of available ind2s  118
# Rejecting this id 150
# id 6 now has  11  contacts
# no. of available ind2s  117
# connected id 6  to id 428  who has 10 connections out of  [11]
# id 6 now has  12  contacts
# no. of available ind2s  117
# Rejecting this id 466
# id 6 now has  12  contacts
# no. of available ind2s  116
# connected id 6  to id 251  who has 9 connections out of  [12]
# id 6 now has  13  contacts
# no. of available ind2s  116
# connected id 6  to id 21  who has 7 connections out of  [7]
# id 6 now has  14  contacts
#
# finding connections for id 7  of area 0  in area 1
# connections needed for id 7 = [15] and connections acheived= 7
# no. of available ind2s  116
# Rejecting this id 439
# id 7 now has  7  contacts
# no. of available ind2s  115
# connected id 7  to id 430  who has 8 connections out of  [9]
# id 7 now has  8  contacts
# no. of available ind2s  115
# connected id 7  to id 125  who has 5 connections out of  [5]
# id 7 now has  9  contacts
# no. of available ind2s  115
# Rejecting this id 125
# id 7 now has  9  contacts
# no. of available ind2s  114
# connected id 7  to id 248  who has 10 connections out of  [10]
# id 7 now has  10  contacts
# no. of available ind2s  114
# connected id 7  to id 286  who has 6 connections out of  [6]
# id 7 now has  11  contacts
# no. of available ind2s  114
# connected id 7  to id 112  who has 7 connections out of  [7]
# id 7 now has  12  contacts
# no. of available ind2s  114
# Rejecting this id 415
# id 7 now has  12  contacts
# no. of available ind2s  113
# connected id 7  to id 429  who has 6 connections out of  [7]
# id 7 now has  13  contacts
# no. of available ind2s  113
# Rejecting this id 277
# id 7 now has  13  contacts
# no. of available ind2s  112
# connected id 7  to id 393  who has 14 connections out of  [15]
# id 7 now has  14  contacts
# no. of available ind2s  112
# connected id 7  to id 199  who has 6 connections out of  [4]
# id 7 now has  15  contacts
#
# finding connections for id 8  of area 0  in area 1
# connections needed for id 8 = [11] and connections acheived= 8
# no. of available ind2s  112
# connected id 8  to id 432  who has 7 connections out of  [5]
# id 8 now has  9  contacts
# no. of available ind2s  112
# connected id 8  to id 283  who has 10 connections out of  [10]
# id 8 now has  10  contacts
# no. of available ind2s  112
# connected id 8  to id 429  who has 7 connections out of  [5]
# id 8 now has  11  contacts
#
# finding connections for id 9  of area 0  in area 1
# connections needed for id 9 = [10] and connections acheived= 5
# no. of available ind2s  112
# connected id 9  to id 147  who has 12 connections out of  [12]
# id 9 now has  6  contacts
# no. of available ind2s  112
# connected id 9  to id 237  who has 10 connections out of  [11]
# id 9 now has  7  contacts
# no. of available ind2s  112
# connected id 9  to id 367  who has 7 connections out of  [10]
# id 9 now has  8  contacts
# no. of available ind2s  112
# connected id 9  to id 145  who has 8 connections out of  [8]
# id 9 now has  9  contacts
# no. of available ind2s  112
# connected id 9  to id 110  who has 8 connections out of  [9]
# id 9 now has  10  contacts
#
# finding connections for id 10  of area 0  in area 1
# connections needed for id 10 = [8] and connections acheived= 6
# no. of available ind2s  112
# connected id 10  to id 130  who has 7 connections out of  [8]
# id 10 now has  7  contacts
# no. of available ind2s  112
# connected id 10  to id 149  who has 10 connections out of  [11]
# id 10 now has  8  contacts
#
# finding connections for id 11  of area 0  in area 1
# connections needed for id 11 = [11] and connections acheived= 5
# no. of available ind2s  112
# Rejecting this id 405
# id 11 now has  5  contacts
# no. of available ind2s  111
# Rejecting this id 126
# id 11 now has  5  contacts
# no. of available ind2s  110
# connected id 11  to id 112  who has 8 connections out of  [9]
# id 11 now has  6  contacts
# no. of available ind2s  110
# connected id 11  to id 272  who has 10 connections out of  [10]
# id 11 now has  7  contacts
# no. of available ind2s  110
# Rejecting this id 112
# id 11 now has  7  contacts
# no. of available ind2s  109
# connected id 11  to id 113  who has 8 connections out of  [11]
# id 11 now has  8  contacts
# no. of available ind2s  109
# connected id 11  to id 294  who has 7 connections out of  [7]
# id 11 now has  9  contacts
# no. of available ind2s  109
# connected id 11  to id 52  who has 5 connections out of  [9]
# id 11 now has  10  contacts
# no. of available ind2s  109
# connected id 11  to id 115  who has 7 connections out of  [9]
# id 11 now has  11  contacts
#
# finding connections for id 12  of area 0  in area 1
# connections needed for id 12 = [14] and connections acheived= 7
# no. of available ind2s  109
# connected id 12  to id 404  who has 9 connections out of  [10]
# id 12 now has  8  contacts
# no. of available ind2s  109
# connected id 12  to id 285  who has 6 connections out of  [10]
# id 12 now has  9  contacts
# no. of available ind2s  109
# Rejecting this id 429
# id 12 now has  9  contacts
# no. of available ind2s  108
# connected id 12  to id 467  who has 6 connections out of  [4]
# id 12 now has  10  contacts
# no. of available ind2s  108
# connected id 12  to id 366  who has 5 connections out of  [6]
# id 12 now has  11  contacts
# no. of available ind2s  108
# connected id 12  to id 249  who has 12 connections out of  [16]
# id 12 now has  12  contacts
# no. of available ind2s  108
# Rejecting this id 259
# id 12 now has  12  contacts
# no. of available ind2s  107
# Rejecting this id 128
# id 12 now has  12  contacts
# no. of available ind2s  106
# connected id 12  to id 88  who has 7 connections out of  [8]
# id 12 now has  13  contacts
# no. of available ind2s  106
# connected id 12  to id 431  who has 9 connections out of  [9]
# id 12 now has  14  contacts
#
# finding connections for id 13  of area 0  in area 1
# connections needed for id 13 = [10] and connections acheived= 6
# no. of available ind2s  106
# connected id 13  to id 52  who has 6 connections out of  [4]
# id 13 now has  7  contacts
# no. of available ind2s  106
# connected id 13  to id 87  who has 8 connections out of  [11]
# id 13 now has  8  contacts
# no. of available ind2s  106
# Rejecting this id 252
# id 13 now has  8  contacts
# no. of available ind2s  105
# connected id 13  to id 235  who has 8 connections out of  [8]
# id 13 now has  9  contacts
# no. of available ind2s  105
# connected id 13  to id 435  who has 13 connections out of  [10]
# id 13 now has  10  contacts
#
# finding connections for id 14  of area 0  in area 1
# connections needed for id 14 = [14] and connections acheived= 7
# no. of available ind2s  105
# connected id 14  to id 275  who has 10 connections out of  [12]
# id 14 now has  8  contacts
# no. of available ind2s  105
# connected id 14  to id 145  who has 9 connections out of  [9]
# id 14 now has  9  contacts
# no. of available ind2s  105
# connected id 14  to id 435  who has 14 connections out of  [7]
# id 14 now has  10  contacts
# no. of available ind2s  105
# connected id 14  to id 124  who has 4 connections out of  [4]
# id 14 now has  11  contacts
# no. of available ind2s  105
# Rejecting this id 465
# id 14 now has  11  contacts
# no. of available ind2s  104
# connected id 14  to id 127  who has 8 connections out of  [11]
# id 14 now has  12  contacts
# no. of available ind2s  104
# connected id 14  to id 337  who has 5 connections out of  [7]
# id 14 now has  13  contacts
# no. of available ind2s  104
# Rejecting this id 178
# id 14 now has  13  contacts
# no. of available ind2s  103
# Rejecting this id 468
# id 14 now has  13  contacts
# no. of available ind2s  102
# connected id 14  to id 234  who has 7 connections out of  [15]
# id 14 now has  14  contacts
#
# finding connections for id 15  of area 0  in area 1
# connections needed for id 15 = [6] and connections acheived= 4
# no. of available ind2s  102
# connected id 15  to id 272  who has 11 connections out of  [14]
# id 15 now has  5  contacts
# no. of available ind2s  102
# connected id 15  to id 393  who has 15 connections out of  [17]
# id 15 now has  6  contacts
#
# finding connections for id 16  of area 0  in area 1
# connections needed for id 16 = [9] and connections acheived= 7
# no. of available ind2s  102
# connected id 16  to id 253  who has 10 connections out of  [10]
# id 16 now has  8  contacts
# no. of available ind2s  102
# Rejecting this id 117
# id 16 now has  8  contacts
# no. of available ind2s  101
# Rejecting this id 436
# id 16 now has  8  contacts
# no. of available ind2s  100
# connected id 16  to id 130  who has 8 connections out of  [8]
# id 16 now has  9  contacts
#
# finding connections for id 17  of area 0  in area 1
# connections needed for id 17 = [9] and connections acheived= 6
# no. of available ind2s  100
# Rejecting this id 115
# id 17 now has  6  contacts
# no. of available ind2s  99
# connected id 17  to id 180  who has 7 connections out of  [5]
# id 17 now has  7  contacts
# no. of available ind2s  99
# Rejecting this id 250
# id 17 now has  7  contacts
# no. of available ind2s  98
# connected id 17  to id 434  who has 13 connections out of  [9]
# id 17 now has  8  contacts
# no. of available ind2s  98
# connected id 17  to id 116  who has 9 connections out of  [10]
# id 17 now has  9  contacts
#
# finding connections for id 18  of area 0  in area 1
# connections needed for id 18 = [11] and connections acheived= 7
# no. of available ind2s  98
# connected id 18  to id 127  who has 9 connections out of  [9]
# id 18 now has  8  contacts
# no. of available ind2s  98
# connected id 18  to id 292  who has 9 connections out of  [9]
# id 18 now has  9  contacts
# no. of available ind2s  98
# connected id 18  to id 431  who has 10 connections out of  [10]
# id 18 now has  10  contacts
# no. of available ind2s  98
# connected id 18  to id 180  who has 8 connections out of  [6]
# id 18 now has  11  contacts
#
# finding connections for id 19  of area 0  in area 1
# connections needed for id 19 = [11] and connections acheived= 10
# no. of available ind2s  98
# connected id 19  to id 276  who has 8 connections out of  [9]
# id 19 now has  11  contacts
#
# finding connections for id 20  of area 0  in area 1
# connections needed for id 20 = [10] and connections acheived= 6
# no. of available ind2s  98
# connected id 20  to id 147  who has 13 connections out of  [16]
# id 20 now has  7  contacts
# no. of available ind2s  98
# connected id 20  to id 276  who has 9 connections out of  [9]
# id 20 now has  8  contacts
# no. of available ind2s  98
# connected id 20  to id 236  who has 5 connections out of  [5]
# id 20 now has  9  contacts
# no. of available ind2s  98
# connected id 20  to id 179  who has 7 connections out of  [9]
# id 20 now has  10  contacts
#
# finding connections for id 24  of area 0  in area 1
# connections needed for id 24 = [11] and connections acheived= 8
# no. of available ind2s  98
# connected id 24  to id 264  who has 9 connections out of  [10]
# id 24 now has  9  contacts
# no. of available ind2s  98
# connected id 24  to id 116  who has 10 connections out of  [11]
# id 24 now has  10  contacts
# no. of available ind2s  98
# connected id 24  to id 428  who has 11 connections out of  [11]
# id 24 now has  11  contacts
#
# finding connections for id 25  of area 0  in area 1
# connections needed for id 25 = [14] and connections acheived= 8
# no. of available ind2s  98
# Rejecting this id 237
# id 25 now has  8  contacts
# no. of available ind2s  97
# connected id 25  to id 403  who has 9 connections out of  [10]
# id 25 now has  9  contacts
# no. of available ind2s  97
# Rejecting this id 403
# id 25 now has  9  contacts
# no. of available ind2s  96
# connected id 25  to id 179  who has 8 connections out of  [9]
# id 25 now has  10  contacts
# no. of available ind2s  96
# Rejecting this id 275
# id 25 now has  10  contacts
# no. of available ind2s  95
# connected id 25  to id 111  who has 7 connections out of  [8]
# id 25 now has  11  contacts
# no. of available ind2s  95
# connected id 25  to id 144  who has 9 connections out of  [11]
# id 25 now has  12  contacts
# no. of available ind2s  95
# connected id 25  to id 113  who has 9 connections out of  [10]
# id 25 now has  13  contacts
# no. of available ind2s  95
# connected id 25  to id 327  who has 10 connections out of  [11]
# id 25 now has  14  contacts
#
# finding connections for id 26  of area 0  in area 1
# connections needed for id 26 = [11] and connections acheived= 8
# no. of available ind2s  95
# Rejecting this id 392
# id 26 now has  8  contacts
# no. of available ind2s  94
# connected id 26  to id 324  who has 9 connections out of  [11]
# id 26 now has  9  contacts
# no. of available ind2s  94
# connected id 26  to id 328  who has 11 connections out of  [13]
# id 26 now has  10  contacts
# no. of available ind2s  94
# connected id 26  to id 276  who has 10 connections out of  [10]
# id 26 now has  11  contacts
#
# finding connections for id 27  of area 0  in area 1
# connections needed for id 27 = [9] and connections acheived= 8
# no. of available ind2s  94
# connected id 27  to id 276  who has 11 connections out of  [7]
# id 27 now has  9  contacts
#
# finding connections for id 28  of area 0  in area 1
# connections needed for id 28 = [9] and connections acheived= 9
#
# finding connections for id 29  of area 0  in area 1
# connections needed for id 29 = [13] and connections acheived= 6
# no. of available ind2s  94
# connected id 29  to id 404  who has 10 connections out of  [11]
# id 29 now has  7  contacts
# no. of available ind2s  94
# connected id 29  to id 21  who has 8 connections out of  [8]
# id 29 now has  8  contacts
# no. of available ind2s  94
# connected id 29  to id 283  who has 11 connections out of  [9]
# id 29 now has  9  contacts
# no. of available ind2s  94
# connected id 29  to id 393  who has 16 connections out of  [16]
# id 29 now has  10  contacts
# no. of available ind2s  94
# connected id 29  to id 272  who has 12 connections out of  [9]
# id 29 now has  11  contacts
# no. of available ind2s  94
# connected id 29  to id 273  who has 10 connections out of  [10]
# id 29 now has  12  contacts
# no. of available ind2s  94
# Rejecting this id 272
# id 29 now has  12  contacts
# no. of available ind2s  93
# connected id 29  to id 53  who has 5 connections out of  [5]
# id 29 now has  13  contacts
#
# finding connections for id 50  of area 0  in area 1
# connections needed for id 50 = [9] and connections acheived= 6
# no. of available ind2s  93
# Rejecting this id 404
# id 50 now has  6  contacts
# no. of available ind2s  92
# Rejecting this id 21
# id 50 now has  6  contacts
# no. of available ind2s  91
# Rejecting this id 130
# id 50 now has  6  contacts
# no. of available ind2s  90
# connected id 50  to id 276  who has 12 connections out of  [8]
# id 50 now has  7  contacts
# no. of available ind2s  90
# connected id 50  to id 295  who has 9 connections out of  [9]
# id 50 now has  8  contacts
# no. of available ind2s  90
# Rejecting this id 235
# id 50 now has  8  contacts
# no. of available ind2s  89
# connected id 50  to id 129  who has 7 connections out of  [7]
# id 50 now has  9  contacts
#
# finding connections for id 51  of area 0  in area 1
# connections needed for id 51 = [8] and connections acheived= 5
# no. of available ind2s  89
# connected id 51  to id 262  who has 8 connections out of  [10]
# id 51 now has  6  contacts
# no. of available ind2s  89
# connected id 51  to id 428  who has 12 connections out of  [10]
# id 51 now has  7  contacts
# no. of available ind2s  89
# Rejecting this id 262
# id 51 now has  7  contacts
# no. of available ind2s  88
# connected id 51  to id 199  who has 7 connections out of  [8]
# id 51 now has  8  contacts
#
# finding connections for id 55  of area 0  in area 1
# connections needed for id 55 = [15] and connections acheived= 9
# no. of available ind2s  88
# connected id 55  to id 198  who has 11 connections out of  [9]
# id 55 now has  10  contacts
# no. of available ind2s  88
# connected id 55  to id 322  who has 10 connections out of  [11]
# id 55 now has  11  contacts
# no. of available ind2s  88
# Rejecting this id 264
# id 55 now has  11  contacts
# no. of available ind2s  87
# connected id 55  to id 179  who has 9 connections out of  [7]
# id 55 now has  12  contacts
# no. of available ind2s  87
# connected id 55  to id 199  who has 8 connections out of  [4]
# id 55 now has  13  contacts
# no. of available ind2s  87
# connected id 55  to id 85  who has 5 connections out of  [5]
# id 55 now has  14  contacts
# no. of available ind2s  87
# Rejecting this id 179
# id 55 now has  14  contacts
# no. of available ind2s  86
# Rejecting this id 180
# id 55 now has  14  contacts
# no. of available ind2s  85
# connected id 55  to id 114  who has 5 connections out of  [7]
# id 55 now has  15  contacts
#
# finding connections for id 56  of area 0  in area 1
# connections needed for id 56 = [10] and connections acheived= 6
# no. of available ind2s  85
# connected id 56  to id 198  who has 12 connections out of  [12]
# id 56 now has  7  contacts
# no. of available ind2s  85
# Rejecting this id 368
# id 56 now has  7  contacts
# no. of available ind2s  84
# connected id 56  to id 426  who has 6 connections out of  [6]
# id 56 now has  8  contacts
# no. of available ind2s  84
# connected id 56  to id 86  who has 8 connections out of  [11]
# id 56 now has  9  contacts
# no. of available ind2s  84
# connected id 56  to id 116  who has 11 connections out of  [9]
# id 56 now has  10  contacts
#
# finding connections for id 57  of area 0  in area 1
# connections needed for id 57 = [8] and connections acheived= 6
# no. of available ind2s  84
# Rejecting this id 111
# id 57 now has  6  contacts
# no. of available ind2s  83
# connected id 57  to id 322  who has 11 connections out of  [9]
# id 57 now has  7  contacts
# no. of available ind2s  83
# Rejecting this id 129
# id 57 now has  7  contacts
# no. of available ind2s  82
# connected id 57  to id 89  who has 6 connections out of  [8]
# id 57 now has  8  contacts
#
# finding connections for id 58  of area 0  in area 1
# connections needed for id 58 = [10] and connections acheived= 4
# no. of available ind2s  82
# connected id 58  to id 234  who has 8 connections out of  [10]
# id 58 now has  5  contacts
# no. of available ind2s  82
# Rejecting this id 263
# id 58 now has  5  contacts
# no. of available ind2s  81
# connected id 58  to id 334  who has 6 connections out of  [8]
# id 58 now has  6  contacts
# no. of available ind2s  81
# connected id 58  to id 428  who has 13 connections out of  [8]
# id 58 now has  7  contacts
# no. of available ind2s  81
# connected id 58  to id 202  who has 4 connections out of  [5]
# id 58 now has  8  contacts
# no. of available ind2s  81
# connected id 58  to id 22  who has 7 connections out of  [7]
# id 58 now has  9  contacts
# no. of available ind2s  81
# connected id 58  to id 430  who has 9 connections out of  [10]
# id 58 now has  10  contacts
#
# finding connections for id 59  of area 0  in area 1
# connections needed for id 59 = [10] and connections acheived= 4
# no. of available ind2s  81
# connected id 59  to id 23  who has 4 connections out of  [5]
# id 59 now has  5  contacts
# no. of available ind2s  81
# connected id 59  to id 127  who has 10 connections out of  [8]
# id 59 now has  6  contacts
# no. of available ind2s  81
# connected id 59  to id 273  who has 11 connections out of  [12]
# id 59 now has  7  contacts
# no. of available ind2s  81
# connected id 59  to id 145  who has 10 connections out of  [8]
# id 59 now has  8  contacts
# no. of available ind2s  81
# Rejecting this id 238
# id 59 now has  8  contacts
# no. of available ind2s  80
# connected id 59  to id 433  who has 10 connections out of  [11]
# id 59 now has  9  contacts
# no. of available ind2s  80
# connected id 59  to id 124  who has 5 connections out of  [3]
# id 59 now has  10  contacts
#
# finding connections for id 60  of area 0  in area 1
# connections needed for id 60 = [13] and connections acheived= 5
# no. of available ind2s  80
# connected id 60  to id 426  who has 7 connections out of  [7]
# id 60 now has  6  contacts
# no. of available ind2s  80
# connected id 60  to id 322  who has 12 connections out of  [9]
# id 60 now has  7  contacts
# no. of available ind2s  80
# connected id 60  to id 285  who has 7 connections out of  [8]
# id 60 now has  8  contacts
# no. of available ind2s  80
# connected id 60  to id 432  who has 8 connections out of  [5]
# id 60 now has  9  contacts
# no. of available ind2s  80
# Rejecting this id 236
# id 60 now has  9  contacts
# no. of available ind2s  79
# Rejecting this id 116
# id 60 now has  9  contacts
# no. of available ind2s  78
# connected id 60  to id 467  who has 7 connections out of  [4]
# id 60 now has  10  contacts
# no. of available ind2s  78
# Rejecting this id 432
# id 60 now has  10  contacts
# no. of available ind2s  77
# connected id 60  to id 335  who has 5 connections out of  [6]
# id 60 now has  11  contacts
# no. of available ind2s  77
# connected id 60  to id 393  who has 17 connections out of  [15]
# id 60 now has  12  contacts
# no. of available ind2s  77
# connected id 60  to id 88  who has 8 connections out of  [8]
# id 60 now has  13  contacts
#
# finding connections for id 61  of area 0  in area 1
# connections needed for id 61 = [10] and connections acheived= 3
# no. of available ind2s  77
# connected id 61  to id 199  who has 9 connections out of  [5]
# id 61 now has  4  contacts
# no. of available ind2s  77
# connected id 61  to id 260  who has 8 connections out of  [9]
# id 61 now has  5  contacts
# no. of available ind2s  77
# Rejecting this id 85
# id 61 now has  5  contacts
# no. of available ind2s  76
# connected id 61  to id 248  who has 11 connections out of  [11]
# id 61 now has  6  contacts
# no. of available ind2s  76
# connected id 61  to id 176  who has 6 connections out of  [9]
# id 61 now has  7  contacts
# no. of available ind2s  76
# Rejecting this id 260
# id 61 now has  7  contacts
# no. of available ind2s  75
# connected id 61  to id 53  who has 6 connections out of  [4]
# id 61 now has  8  contacts
# no. of available ind2s  75
# connected id 61  to id 110  who has 9 connections out of  [7]
# id 61 now has  9  contacts
# no. of available ind2s  75
# connected id 61  to id 434  who has 14 connections out of  [8]
# id 61 now has  10  contacts
#
# finding connections for id 62  of area 0  in area 1
# connections needed for id 62 = [13] and connections acheived= 7
# no. of available ind2s  75
# connected id 62  to id 434  who has 15 connections out of  [11]
# id 62 now has  8  contacts
# no. of available ind2s  75
# connected id 62  to id 200  who has 6 connections out of  [8]
# id 62 now has  9  contacts
# no. of available ind2s  75
# Rejecting this id 337
# id 62 now has  9  contacts
# no. of available ind2s  74
# connected id 62  to id 177  who has 8 connections out of  [8]
# id 62 now has  10  contacts
# no. of available ind2s  74
# Rejecting this id 110
# id 62 now has  10  contacts
# no. of available ind2s  73
# connected id 62  to id 127  who has 11 connections out of  [7]
# id 62 now has  11  contacts
# no. of available ind2s  73
# connected id 62  to id 199  who has 10 connections out of  [6]
# id 62 now has  12  contacts
# no. of available ind2s  73
# connected id 62  to id 428  who has 14 connections out of  [10]
# id 62 now has  13  contacts
#
# finding connections for id 63  of area 0  in area 1
# connections needed for id 63 = [8] and connections acheived= 4
# no. of available ind2s  73
# connected id 63  to id 286  who has 7 connections out of  [7]
# id 63 now has  5  contacts
# no. of available ind2s  73
# connected id 63  to id 201  who has 6 connections out of  [7]
# id 63 now has  6  contacts
# no. of available ind2s  73
# connected id 63  to id 276  who has 13 connections out of  [9]
# id 63 now has  7  contacts
# no. of available ind2s  73
# connected id 63  to id 426  who has 8 connections out of  [8]
# id 63 now has  8  contacts
#
# finding connections for id 90  of area 0  in area 1
# connections needed for id 90 = [11] and connections acheived= 9
# no. of available ind2s  73
# Rejecting this id 200
# id 90 now has  9  contacts
# no. of available ind2s  72
# connected id 90  to id 293  who has 11 connections out of  [13]
# id 90 now has  10  contacts
# no. of available ind2s  72
# connected id 90  to id 52  who has 7 connections out of  [4]
# id 90 now has  11  contacts
#
# finding connections for id 91  of area 0  in area 1
# connections needed for id 91 = [11] and connections acheived= 7
# no. of available ind2s  72
# connected id 91  to id 325  who has 13 connections out of  [13]
# id 91 now has  8  contacts
# no. of available ind2s  72
# connected id 91  to id 284  who has 6 connections out of  [6]
# id 91 now has  9  contacts
# no. of available ind2s  72
# connected id 91  to id 327  who has 11 connections out of  [9]
# id 91 now has  10  contacts
# no. of available ind2s  72
# connected id 91  to id 234  who has 9 connections out of  [7]
# id 91 now has  11  contacts
#
# finding connections for id 92  of area 0  in area 1
# connections needed for id 92 = [14] and connections acheived= 9
# no. of available ind2s  72
# connected id 92  to id 276  who has 14 connections out of  [8]
# id 92 now has  10  contacts
# no. of available ind2s  72
# connected id 92  to id 393  who has 18 connections out of  [13]
# id 92 now has  11  contacts
# no. of available ind2s  72
# Rejecting this id 335
# id 92 now has  11  contacts
# no. of available ind2s  71
# connected id 92  to id 113  who has 10 connections out of  [8]
# id 92 now has  12  contacts
# no. of available ind2s  71
# connected id 92  to id 295  who has 10 connections out of  [10]
# id 92 now has  13  contacts
# no. of available ind2s  71
# connected id 92  to id 273  who has 12 connections out of  [9]
# id 92 now has  14  contacts
#
# finding connections for id 93  of area 0  in area 1
# connections needed for id 93 = [14] and connections acheived= 10
# no. of available ind2s  71
# Rejecting this id 202
# id 93 now has  10  contacts
# no. of available ind2s  70
# connected id 93  to id 22  who has 8 connections out of  [6]
# id 93 now has  11  contacts
# no. of available ind2s  70
# connected id 93  to id 327  who has 12 connections out of  [10]
# id 93 now has  12  contacts
# no. of available ind2s  70
# connected id 93  to id 437  who has 10 connections out of  [7]
# id 93 now has  13  contacts
# no. of available ind2s  70
# connected id 93  to id 145  who has 11 connections out of  [8]
# id 93 now has  14  contacts
#
# finding connections for id 94  of area 0  in area 1
# connections needed for id 94 = [11] and connections acheived= 8
# no. of available ind2s  70
# connected id 94  to id 440  who has 12 connections out of  [10]
# id 94 now has  9  contacts
# no. of available ind2s  70
# connected id 94  to id 334  who has 7 connections out of  [8]
# id 94 now has  10  contacts
# no. of available ind2s  70
# connected id 94  to id 433  who has 11 connections out of  [7]
# id 94 now has  11  contacts
#
# finding connections for id 95  of area 0  in area 1
# connections needed for id 95 = [16] and connections acheived= 10
# no. of available ind2s  70
# connected id 95  to id 124  who has 6 connections out of  [4]
# id 95 now has  11  contacts
# no. of available ind2s  70
# connected id 95  to id 434  who has 16 connections out of  [11]
# id 95 now has  12  contacts
# no. of available ind2s  70
# connected id 95  to id 114  who has 6 connections out of  [4]
# id 95 now has  13  contacts
# no. of available ind2s  70
# connected id 95  to id 438  who has 11 connections out of  [8]
# id 95 now has  14  contacts
# no. of available ind2s  70
# connected id 95  to id 113  who has 11 connections out of  [9]
# id 95 now has  15  contacts
# no. of available ind2s  70
# connected id 95  to id 53  who has 7 connections out of  [5]
# id 95 now has  16  contacts
#
# finding connections for id 96  of area 0  in area 1
# connections needed for id 96 = [13] and connections acheived= 8
# no. of available ind2s  70
# connected id 96  to id 249  who has 13 connections out of  [14]
# id 96 now has  9  contacts
# no. of available ind2s  70
# connected id 96  to id 284  who has 7 connections out of  [4]
# id 96 now has  10  contacts
# no. of available ind2s  70
# connected id 96  to id 296  who has 13 connections out of  [13]
# id 96 now has  11  contacts
# no. of available ind2s  70
# connected id 96  to id 285  who has 8 connections out of  [5]
# id 96 now has  12  contacts
# no. of available ind2s  70
# connected id 96  to id 426  who has 9 connections out of  [7]
# id 96 now has  13  contacts
#
# finding connections for id 98  of area 0  in area 1
# connections needed for id 98 = [11] and connections acheived= 9
# no. of available ind2s  70
# connected id 98  to id 271  who has 12 connections out of  [14]
# id 98 now has  10  contacts
# no. of available ind2s  70
# connected id 98  to id 292  who has 10 connections out of  [10]
# id 98 now has  11  contacts
#
# finding connections for id 99  of area 0  in area 1
# connections needed for id 99 = [9] and connections acheived= 8
# no. of available ind2s  70
# Rejecting this id 54
# id 99 now has  8  contacts
# no. of available ind2s  69
# connected id 99  to id 294  who has 8 connections out of  [10]
# id 99 now has  9  contacts
#
# finding connections for id 100  of area 0  in area 1
# connections needed for id 100 = [13] and connections acheived= 10
# no. of available ind2s  69
# connected id 100  to id 294  who has 9 connections out of  [6]
# id 100 now has  11  contacts
# no. of available ind2s  69
# connected id 100  to id 114  who has 7 connections out of  [4]
# id 100 now has  12  contacts
# no. of available ind2s  69
# connected id 100  to id 249  who has 14 connections out of  [11]
# id 100 now has  13  contacts
#
# finding connections for id 101  of area 0  in area 1
# connections needed for id 101 = [10] and connections acheived= 6
# no. of available ind2s  69
# connected id 101  to id 177  who has 9 connections out of  [9]
# id 101 now has  7  contacts
# no. of available ind2s  69
# Rejecting this id 53
# id 101 now has  7  contacts
# no. of available ind2s  68
# connected id 101  to id 86  who has 9 connections out of  [11]
# id 101 now has  8  contacts
# no. of available ind2s  68
# connected id 101  to id 234  who has 10 connections out of  [8]
# id 101 now has  9  contacts
# no. of available ind2s  68
# connected id 101  to id 433  who has 12 connections out of  [9]
# id 101 now has  10  contacts
#
# finding connections for id 102  of area 0  in area 1
# connections needed for id 102 = [15] and connections acheived= 10
# no. of available ind2s  68
# connected id 102  to id 435  who has 15 connections out of  [10]
# id 102 now has  11  contacts
# no. of available ind2s  68
# connected id 102  to id 234  who has 11 connections out of  [11]
# id 102 now has  12  contacts
# no. of available ind2s  68
# connected id 102  to id 247  who has 10 connections out of  [11]
# id 102 now has  13  contacts
# no. of available ind2s  68
# connected id 102  to id 114  who has 8 connections out of  [4]
# id 102 now has  14  contacts
# no. of available ind2s  68
# connected id 102  to id 417  who has 3 connections out of  [5]
# id 102 now has  15  contacts
#
# finding connections for id 103  of area 0  in area 1
# connections needed for id 103 = [17] and connections acheived= 8
# no. of available ind2s  68
# connected id 103  to id 114  who has 9 connections out of  [6]
# id 103 now has  9  contacts
# no. of available ind2s  68
# connected id 103  to id 198  who has 13 connections out of  [9]
# id 103 now has  10  contacts
# no. of available ind2s  68
# Rejecting this id 114
# id 103 now has  10  contacts
# no. of available ind2s  67
# connected id 103  to id 261  who has 9 connections out of  [10]
# id 103 now has  11  contacts
# no. of available ind2s  67
# connected id 103  to id 283  who has 12 connections out of  [9]
# id 103 now has  12  contacts
# no. of available ind2s  67
# connected id 103  to id 249  who has 15 connections out of  [13]
# id 103 now has  13  contacts
# no. of available ind2s  67
# connected id 103  to id 253  who has 11 connections out of  [13]
# id 103 now has  14  contacts
# no. of available ind2s  67
# connected id 103  to id 248  who has 12 connections out of  [9]
# id 103 now has  15  contacts
# no. of available ind2s  67
# connected id 103  to id 435  who has 16 connections out of  [11]
# id 103 now has  16  contacts
# no. of available ind2s  67
# Rejecting this id 198
# id 103 now has  16  contacts
# no. of available ind2s  66
# connected id 103  to id 406  who has 7 connections out of  [11]
# id 103 now has  17  contacts
#
# finding connections for id 104  of area 0  in area 1
# connections needed for id 104 = [8] and connections acheived= 6
# no. of available ind2s  66
# connected id 104  to id 428  who has 15 connections out of  [9]
# id 104 now has  7  contacts
# no. of available ind2s  66
# connected id 104  to id 438  who has 12 connections out of  [8]
# id 104 now has  8  contacts
#
# finding connections for id 118  of area 0  in area 1
# connections needed for id 118 = [11] and connections acheived= 10
# no. of available ind2s  66
# connected id 118  to id 124  who has 7 connections out of  [3]
# id 118 now has  11  contacts
#
# finding connections for id 119  of area 0  in area 1
# connections needed for id 119 = [8] and connections acheived= 6
# no. of available ind2s  66
# connected id 119  to id 146  who has 10 connections out of  [10]
# id 119 now has  7  contacts
# no. of available ind2s  66
# connected id 119  to id 276  who has 15 connections out of  [10]
# id 119 now has  8  contacts
#
# finding connections for id 120  of area 0  in area 1
# connections needed for id 120 = [11] and connections acheived= 8
# no. of available ind2s  66
# connected id 120  to id 434  who has 17 connections out of  [8]
# id 120 now has  9  contacts
# no. of available ind2s  66
# connected id 120  to id 284  who has 8 connections out of  [6]
# id 120 now has  10  contacts
# no. of available ind2s  66
# Rejecting this id 325
# id 120 now has  10  contacts
# no. of available ind2s  65
# Rejecting this id 147
# id 120 now has  10  contacts
# no. of available ind2s  64
# connected id 120  to id 261  who has 10 connections out of  [10]
# id 120 now has  11  contacts
#
# finding connections for id 121  of area 0  in area 1
# connections needed for id 121 = [12] and connections acheived= 7
# no. of available ind2s  64
# connected id 121  to id 324  who has 10 connections out of  [7]
# id 121 now has  8  contacts
# no. of available ind2s  64
# connected id 121  to id 89  who has 7 connections out of  [8]
# id 121 now has  9  contacts
# no. of available ind2s  64
# connected id 121  to id 440  who has 13 connections out of  [9]
# id 121 now has  10  contacts
# no. of available ind2s  64
# connected id 121  to id 292  who has 11 connections out of  [8]
# id 121 now has  11  contacts
# no. of available ind2s  64
# connected id 121  to id 416  who has 5 connections out of  [3]
# id 121 now has  12  contacts
#
# finding connections for id 122  of area 0  in area 1
# connections needed for id 122 = [10] and connections acheived= 9
# no. of available ind2s  64
# connected id 122  to id 393  who has 19 connections out of  [13]
# id 122 now has  10  contacts
#
# finding connections for id 123  of area 0  in area 1
# connections needed for id 123 = [13] and connections acheived= 9
# no. of available ind2s  64
# connected id 123  to id 416  who has 6 connections out of  [3]
# id 123 now has  10  contacts
# no. of available ind2s  64
# connected id 123  to id 294  who has 10 connections out of  [8]
# id 123 now has  11  contacts
# no. of available ind2s  64
# Rejecting this id 326
# id 123 now has  11  contacts
# no. of available ind2s  63
# connected id 123  to id 438  who has 13 connections out of  [9]
# id 123 now has  12  contacts
# no. of available ind2s  63
# connected id 123  to id 276  who has 16 connections out of  [9]
# id 123 now has  13  contacts
#
# finding connections for id 139  of area 0  in area 1
# connections needed for id 139 = [10] and connections acheived= 5
# no. of available ind2s  63
# connected id 139  to id 324  who has 11 connections out of  [7]
# id 139 now has  6  contacts
# no. of available ind2s  63
# connected id 139  to id 23  who has 5 connections out of  [3]
# id 139 now has  7  contacts
# no. of available ind2s  63
# Rejecting this id 437
# id 139 now has  7  contacts
# no. of available ind2s  62
# connected id 139  to id 434  who has 18 connections out of  [10]
# id 139 now has  8  contacts
# no. of available ind2s  62
# connected id 139  to id 149  who has 11 connections out of  [9]
# id 139 now has  9  contacts
# no. of available ind2s  62
# connected id 139  to id 146  who has 11 connections out of  [12]
# id 139 now has  10  contacts
#
# finding connections for id 140  of area 0  in area 1
# connections needed for id 140 = [11] and connections acheived= 6
# no. of available ind2s  62
# Rejecting this id 144
# id 140 now has  6  contacts
# no. of available ind2s  61
# connected id 140  to id 440  who has 14 connections out of  [11]
# id 140 now has  7  contacts
# no. of available ind2s  61
# connected id 140  to id 52  who has 8 connections out of  [10]
# id 140 now has  8  contacts
# no. of available ind2s  61
# connected id 140  to id 177  who has 10 connections out of  [10]
# id 140 now has  9  contacts
# no. of available ind2s  61
# connected id 140  to id 334  who has 8 connections out of  [9]
# id 140 now has  10  contacts
# no. of available ind2s  61
# connected id 140  to id 328  who has 12 connections out of  [13]
# id 140 now has  11  contacts
#
# finding connections for id 155  of area 0  in area 1
# connections needed for id 155 = [13] and connections acheived= 10
# no. of available ind2s  61
# connected id 155  to id 285  who has 9 connections out of  [6]
# id 155 now has  11  contacts
# no. of available ind2s  61
# connected id 155  to id 199  who has 11 connections out of  [7]
# id 155 now has  12  contacts
# no. of available ind2s  61
# connected id 155  to id 367  who has 8 connections out of  [9]
# id 155 now has  13  contacts
#
# finding connections for id 156  of area 0  in area 1
# connections needed for id 156 = [12] and connections acheived= 7
# no. of available ind2s  61
# connected id 156  to id 428  who has 16 connections out of  [7]
# id 156 now has  8  contacts
# no. of available ind2s  61
# connected id 156  to id 284  who has 9 connections out of  [7]
# id 156 now has  9  contacts
# no. of available ind2s  61
# connected id 156  to id 249  who has 16 connections out of  [11]
# id 156 now has  10  contacts
# no. of available ind2s  61
# connected id 156  to id 89  who has 8 connections out of  [10]
# id 156 now has  11  contacts
# no. of available ind2s  61
# connected id 156  to id 23  who has 6 connections out of  [3]
# id 156 now has  12  contacts
#
# finding connections for id 157  of area 0  in area 1
# connections needed for id 157 = [14] and connections acheived= 10
# no. of available ind2s  61
# connected id 157  to id 438  who has 14 connections out of  [9]
# id 157 now has  11  contacts
# no. of available ind2s  61
# connected id 157  to id 149  who has 12 connections out of  [10]
# id 157 now has  12  contacts
# no. of available ind2s  61
# connected id 157  to id 393  who has 20 connections out of  [14]
# id 157 now has  13  contacts
# no. of available ind2s  61
# connected id 157  to id 328  who has 13 connections out of  [10]
# id 157 now has  14  contacts
#
# finding connections for id 158  of area 0  in area 1
# connections needed for id 158 = [10] and connections acheived= 7
# no. of available ind2s  61
# connected id 158  to id 285  who has 10 connections out of  [7]
# id 158 now has  8  contacts
# no. of available ind2s  61
# connected id 158  to id 127  who has 12 connections out of  [9]
# id 158 now has  9  contacts
# no. of available ind2s  61
# connected id 158  to id 149  who has 13 connections out of  [11]
# id 158 now has  10  contacts
#
# finding connections for id 159  of area 0  in area 1
# connections needed for id 159 = [12] and connections acheived= 9
# no. of available ind2s  61
# connected id 159  to id 367  who has 9 connections out of  [9]
# id 159 now has  10  contacts
# no. of available ind2s  61
# connected id 159  to id 407  who has 6 connections out of  [6]
# id 159 now has  11  contacts
# no. of available ind2s  61
# connected id 159  to id 52  who has 9 connections out of  [4]
# id 159 now has  12  contacts
#
# finding connections for id 160  of area 0  in area 1
# connections needed for id 160 = [15] and connections acheived= 12
# no. of available ind2s  61
# connected id 160  to id 435  who has 17 connections out of  [12]
# id 160 now has  13  contacts
# no. of available ind2s  61
# connected id 160  to id 323  who has 7 connections out of  [8]
# id 160 now has  14  contacts
# no. of available ind2s  61
# connected id 160  to id 201  who has 7 connections out of  [8]
# id 160 now has  15  contacts
#
# finding connections for id 161  of area 0  in area 1
# connections needed for id 161 = [15] and connections acheived= 12
# no. of available ind2s  61
# connected id 161  to id 273  who has 13 connections out of  [10]
# id 161 now has  13  contacts
# no. of available ind2s  61
# connected id 161  to id 247  who has 11 connections out of  [12]
# id 161 now has  14  contacts
# no. of available ind2s  61
# connected id 161  to id 433  who has 13 connections out of  [9]
# id 161 now has  15  contacts
#
# finding connections for id 162  of area 0  in area 1
# connections needed for id 162 = [14] and connections acheived= 8
# no. of available ind2s  61
# connected id 162  to id 324  who has 12 connections out of  [7]
# id 162 now has  9  contacts
# no. of available ind2s  61
# Rejecting this id 201
# id 162 now has  9  contacts
# no. of available ind2s  60
# connected id 162  to id 276  who has 17 connections out of  [10]
# id 162 now has  10  contacts
# no. of available ind2s  60
# Rejecting this id 292
# id 162 now has  10  contacts
# no. of available ind2s  59
# connected id 162  to id 334  who has 9 connections out of  [5]
# id 162 now has  11  contacts
# no. of available ind2s  59
# connected id 162  to id 433  who has 14 connections out of  [10]
# id 162 now has  12  contacts
# no. of available ind2s  59
# Rejecting this id 430
# id 162 now has  12  contacts
# no. of available ind2s  58
# connected id 162  to id 426  who has 10 connections out of  [6]
# id 162 now has  13  contacts
# no. of available ind2s  58
# connected id 162  to id 393  who has 21 connections out of  [16]
# id 162 now has  14  contacts
#
# finding connections for id 163  of area 0  in area 1
# connections needed for id 163 = [14] and connections acheived= 5
# no. of available ind2s  58
# connected id 163  to id 435  who has 18 connections out of  [9]
# id 163 now has  6  contacts
# no. of available ind2s  58
# connected id 163  to id 428  who has 17 connections out of  [8]
# id 163 now has  7  contacts
# no. of available ind2s  58
# Rejecting this id 89
# id 163 now has  7  contacts
# no. of available ind2s  57
# connected id 163  to id 253  who has 12 connections out of  [10]
# id 163 now has  8  contacts
# no. of available ind2s  57
# Rejecting this id 271
# id 163 now has  8  contacts
# no. of available ind2s  56
# connected id 163  to id 273  who has 14 connections out of  [10]
# id 163 now has  9  contacts
# no. of available ind2s  56
# Rejecting this id 391
# id 163 now has  9  contacts
# no. of available ind2s  55
# Rejecting this id 176
# id 163 now has  9  contacts
# no. of available ind2s  54
# connected id 163  to id 366  who has 6 connections out of  [6]
# id 163 now has  10  contacts
# no. of available ind2s  54
# connected id 163  to id 86  who has 10 connections out of  [10]
# id 163 now has  11  contacts
# no. of available ind2s  54
# connected id 163  to id 438  who has 15 connections out of  [8]
# id 163 now has  12  contacts
# no. of available ind2s  54
# connected id 163  to id 431  who has 11 connections out of  [13]
# id 163 now has  13  contacts
# no. of available ind2s  54
# connected id 163  to id 334  who has 10 connections out of  [6]
# id 163 now has  14  contacts
#
# finding connections for id 164  of area 0  in area 1
# connections needed for id 164 = [11] and connections acheived= 8
# no. of available ind2s  54
# connected id 164  to id 406  who has 8 connections out of  [8]
# id 164 now has  9  contacts
# no. of available ind2s  54
# connected id 164  to id 127  who has 13 connections out of  [9]
# id 164 now has  10  contacts
# no. of available ind2s  54
# Rejecting this id 148
# id 164 now has  10  contacts
# no. of available ind2s  53
# ...
# no. of available ind2s  140
# connected id 334  to id 41  who has 13 connections out of  [8]
# id 334 now has  19  contacts
# no. of available ind2s  140
# Rejecting this id 79
# id 334 now has  19  contacts
# no. of available ind2s  139
# connected id 334  to id 340  who has 16 connections out of  [10]
# id 334 now has  20  contacts
# no. of available ind2s  139
# connected id 334  to id 220  who has 8 connections out of  [9]
# id 334 now has  21  contacts
#
# finding connections for id 335  of area 1  in area 2
# connections needed for id 335 = [8] and connections acheived= 5
# no. of available ind2s  139
# connected id 335  to id 106  who has 13 connections out of  [10]
# id 335 now has  6  contacts
# no. of available ind2s  139
# connected id 335  to id 351  who has 10 connections out of  [11]
# id 335 now has  7  contacts
# no. of available ind2s  139
# connected id 335  to id 413  who has 7 connections out of  [5]
# id 335 now has  8  contacts
#
# finding connections for id 336  of area 1  in area 2
# connections needed for id 336 = [8] and connections acheived= 6
# no. of available ind2s  139
# Rejecting this id 311
# id 336 now has  6  contacts
# no. of available ind2s  138
# connected id 336  to id 108  who has 11 connections out of  [12]
# id 336 now has  7  contacts
# no. of available ind2s  138
# connected id 336  to id 189  who has 6 connections out of  [7]
# id 336 now has  8  contacts
#
# finding connections for id 337  of area 1  in area 2
# connections needed for id 337 = [7] and connections acheived= 5
# no. of available ind2s  138
# connected id 337  to id 40  who has 12 connections out of  [12]
# id 337 now has  6  contacts
# no. of available ind2s  138
# connected id 337  to id 339  who has 12 connections out of  [8]
# id 337 now has  7  contacts
#
# finding connections for id 366  of area 1  in area 2
# connections needed for id 366 = [22] and connections acheived= 19
# no. of available ind2s  138
# connected id 366  to id 371  who has 7 connections out of  [5]
# id 366 now has  20  contacts
# no. of available ind2s  138
# Rejecting this id 342
# id 366 now has  20  contacts
# no. of available ind2s  137
# connected id 366  to id 143  who has 9 connections out of  [7]
# id 366 now has  21  contacts
# no. of available ind2s  137
# connected id 366  to id 313  who has 13 connections out of  [10]
# id 366 now has  22  contacts
#
# finding connections for id 367  of area 1  in area 2
# connections needed for id 367 = [25] and connections acheived= 23
# no. of available ind2s  137
# connected id 367  to id 219  who has 8 connections out of  [6]
# id 367 now has  24  contacts
# no. of available ind2s  137
# connected id 367  to id 37  who has 10 connections out of  [8]
# id 367 now has  25  contacts
#
# finding connections for id 368  of area 1  in area 2
# connections needed for id 368 = [9] and connections acheived= 5
# no. of available ind2s  137
# connected id 368  to id 107  who has 12 connections out of  [8]
# id 368 now has  6  contacts
# no. of available ind2s  137
# connected id 368  to id 461  who has 13 connections out of  [10]
# id 368 now has  7  contacts
# no. of available ind2s  137
# Rejecting this id 222
# id 368 now has  7  contacts
# no. of available ind2s  136
# connected id 368  to id 363  who has 16 connections out of  [8]
# id 368 now has  8  contacts
# no. of available ind2s  136
# connected id 368  to id 314  who has 8 connections out of  [6]
# id 368 now has  9  contacts
#
# finding connections for id 369  of area 1  in area 2
# connections needed for id 369 = [7] and connections acheived= 5
# no. of available ind2s  136
# connected id 369  to id 352  who has 10 connections out of  [12]
# id 369 now has  6  contacts
# no. of available ind2s  136
# connected id 369  to id 457  who has 17 connections out of  [14]
# id 369 now has  7  contacts
#
# finding connections for id 390  of area 1  in area 2
# connections needed for id 390 = [8] and connections acheived= 8
#
# finding connections for id 391  of area 1  in area 2
# connections needed for id 391 = [5] and connections acheived= 5
#
# finding connections for id 392  of area 1  in area 2
# connections needed for id 392 = [10] and connections acheived= 7
# no. of available ind2s  136
# connected id 392  to id 174  who has 10 connections out of  [12]
# id 392 now has  8  contacts
# no. of available ind2s  136
# Rejecting this id 136
# id 392 now has  8  contacts
# no. of available ind2s  135
# connected id 392  to id 459  who has 11 connections out of  [12]
# id 392 now has  9  contacts
# no. of available ind2s  135
# connected id 392  to id 375  who has 8 connections out of  [6]
# id 392 now has  10  contacts
#
# finding connections for id 393  of area 1  in area 2
# connections needed for id 393 = [35] and connections acheived= 31
# no. of available ind2s  135
# connected id 393  to id 244  who has 13 connections out of  [13]
# id 393 now has  32  contacts
# no. of available ind2s  135
# connected id 393  to id 77  who has 15 connections out of  [13]
# id 393 now has  33  contacts
# no. of available ind2s  135
# connected id 393  to id 143  who has 10 connections out of  [5]
# id 393 now has  34  contacts
# no. of available ind2s  135
# Rejecting this id 45
# id 393 now has  34  contacts
# no. of available ind2s  134
# connected id 393  to id 381  who has 12 connections out of  [10]
# id 393 now has  35  contacts
#
# finding connections for id 394  of area 1  in area 2
# connections needed for id 394 = [8] and connections acheived= 8
#
# finding connections for id 403  of area 1  in area 2
# connections needed for id 403 = [9] and connections acheived= 9
#
# finding connections for id 404  of area 1  in area 2
# connections needed for id 404 = [13] and connections acheived= 10
# no. of available ind2s  134
# connected id 404  to id 71  who has 14 connections out of  [11]
# id 404 now has  11  contacts
# no. of available ind2s  134
# Rejecting this id 370
# id 404 now has  11  contacts
# no. of available ind2s  133
# connected id 404  to id 382  who has 16 connections out of  [8]
# id 404 now has  12  contacts
# no. of available ind2s  133
# connected id 404  to id 30  who has 17 connections out of  [12]
# id 404 now has  13  contacts
#
# finding connections for id 405  of area 1  in area 2
# connections needed for id 405 = [7] and connections acheived= 5
# no. of available ind2s  133
# connected id 405  to id 377  who has 17 connections out of  [7]
# id 405 now has  6  contacts
# no. of available ind2s  133
# connected id 405  to id 41  who has 14 connections out of  [10]
# id 405 now has  7  contacts
#
# finding connections for id 406  of area 1  in area 2
# connections needed for id 406 = [9] and connections acheived= 9
#
# finding connections for id 407  of area 1  in area 2
# connections needed for id 407 = [8] and connections acheived= 7
# no. of available ind2s  133
# connected id 407  to id 73  who has 10 connections out of  [11]
# id 407 now has  8  contacts
#
# finding connections for id 415  of area 1  in area 2
# connections needed for id 415 = [9] and connections acheived= 7
# no. of available ind2s  133
# connected id 415  to id 43  who has 14 connections out of  [9]
# id 415 now has  8  contacts
# no. of available ind2s  133
# connected id 415  to id 338  who has 19 connections out of  [13]
# id 415 now has  9  contacts
#
# finding connections for id 416  of area 1  in area 2
# connections needed for id 416 = [14] and connections acheived= 10
# no. of available ind2s  133
# Rejecting this id 442
# id 416 now has  10  contacts
# no. of available ind2s  132
# connected id 416  to id 167  who has 9 connections out of  [5]
# id 416 now has  11  contacts
# no. of available ind2s  132
# connected id 416  to id 175  who has 14 connections out of  [10]
# id 416 now has  12  contacts
# no. of available ind2s  132
# Rejecting this id 281
# id 416 now has  12  contacts
# no. of available ind2s  131
# Rejecting this id 258
# id 416 now has  12  contacts
# no. of available ind2s  130
# connected id 416  to id 195  who has 10 connections out of  [7]
# id 416 now has  13  contacts
# no. of available ind2s  130
# connected id 416  to id 34  who has 15 connections out of  [13]
# id 416 now has  14  contacts
#
# finding connections for id 417  of area 1  in area 2
# connections needed for id 417 = [11] and connections acheived= 6
# no. of available ind2s  130
# connected id 417  to id 151  who has 11 connections out of  [5]
# id 417 now has  7  contacts
# no. of available ind2s  130
# connected id 417  to id 168  who has 10 connections out of  [5]
# id 417 now has  8  contacts
# no. of available ind2s  130
# connected id 417  to id 242  who has 12 connections out of  [10]
# id 417 now has  9  contacts
# no. of available ind2s  130
# connected id 417  to id 306  who has 11 connections out of  [11]
# id 417 now has  10  contacts
# no. of available ind2s  130
# connected id 417  to id 31  who has 16 connections out of  [7]
# id 417 now has  11  contacts
#
# finding connections for id 426  of area 1  in area 2
# connections needed for id 426 = [17] and connections acheived= 16
# no. of available ind2s  130
# connected id 426  to id 351  who has 11 connections out of  [12]
# id 426 now has  17  contacts
#
# finding connections for id 427  of area 1  in area 2
# connections needed for id 427 = [6] and connections acheived= 4
# no. of available ind2s  130
# connected id 427  to id 379  who has 14 connections out of  [10]
# id 427 now has  5  contacts
# no. of available ind2s  130
# Rejecting this id 78
# id 427 now has  5  contacts
# no. of available ind2s  129
# Rejecting this id 38
# id 427 now has  5  contacts
# no. of available ind2s  128
# connected id 427  to id 39  who has 19 connections out of  [10]
# id 427 now has  6  contacts
#
# finding connections for id 428  of area 1  in area 2
# connections needed for id 428 = [38] and connections acheived= 35
# no. of available ind2s  128
# connected id 428  to id 460  who has 13 connections out of  [10]
# id 428 now has  36  contacts
# no. of available ind2s  128
# connected id 428  to id 65  who has 15 connections out of  [7]
# id 428 now has  37  contacts
# no. of available ind2s  128
# connected id 428  to id 153  who has 12 connections out of  [9]
# id 428 now has  38  contacts
#
# finding connections for id 429  of area 1  in area 2
# connections needed for id 429 = [9] and connections acheived= 7
# no. of available ind2s  128
# connected id 429  to id 288  who has 15 connections out of  [12]
# id 429 now has  8  contacts
# no. of available ind2s  128
# connected id 429  to id 352  who has 11 connections out of  [9]
# id 429 now has  9  contacts
#
# finding connections for id 430  of area 1  in area 2
# connections needed for id 430 = [9] and connections acheived= 9
#
# finding connections for id 431  of area 1  in area 2
# connections needed for id 431 = [23] and connections acheived= 21
# no. of available ind2s  128
# connected id 431  to id 459  who has 12 connections out of  [9]
# id 431 now has  22  contacts
# no. of available ind2s  128
# connected id 431  to id 363  who has 17 connections out of  [9]
# id 431 now has  23  contacts
#
# finding connections for id 432  of area 1  in area 2
# connections needed for id 432 = [10] and connections acheived= 8
# no. of available ind2s  128
# Rejecting this id 142
# id 432 now has  8  contacts
# no. of available ind2s  127
# connected id 432  to id 377  who has 18 connections out of  [9]
# id 432 now has  9  contacts
# no. of available ind2s  127
# connected id 432  to id 42  who has 13 connections out of  [10]
# id 432 now has  10  contacts
#
# finding connections for id 433  of area 1  in area 2
# connections needed for id 433 = [20] and connections acheived= 17
# no. of available ind2s  127
# connected id 433  to id 460  who has 14 connections out of  [11]
# id 433 now has  18  contacts
# no. of available ind2s  127
# Rejecting this id 312
# id 433 now has  18  contacts
# no. of available ind2s  126
# connected id 433  to id 458  who has 20 connections out of  [9]
# id 433 now has  19  contacts
# no. of available ind2s  126
# connected id 433  to id 413  who has 8 connections out of  [5]
# id 433 now has  20  contacts
#
# finding connections for id 434  of area 1  in area 2
# connections needed for id 434 = [41] and connections acheived= 37
# no. of available ind2s  126
# connected id 434  to id 151  who has 12 connections out of  [6]
# id 434 now has  38  contacts
# no. of available ind2s  126
# connected id 434  to id 141  who has 10 connections out of  [4]
# id 434 now has  39  contacts
# no. of available ind2s  126
# connected id 434  to id 221  who has 4 connections out of  [5]
# id 434 now has  40  contacts
# no. of available ind2s  126
# connected id 434  to id 219  who has 9 connections out of  [5]
# id 434 now has  41  contacts
#
# finding connections for id 435  of area 1  in area 2
# connections needed for id 435 = [32] and connections acheived= 32
#
# finding connections for id 436  of area 1  in area 2
# connections needed for id 436 = [11] and connections acheived= 8
# no. of available ind2s  126
# connected id 436  to id 457  who has 18 connections out of  [14]
# id 436 now has  9  contacts
# no. of available ind2s  126
# connected id 436  to id 460  who has 15 connections out of  [10]
# id 436 now has  10  contacts
# no. of available ind2s  126
# connected id 436  to id 413  who has 9 connections out of  [5]
# id 436 now has  11  contacts
#
# finding connections for id 437  of area 1  in area 2
# connections needed for id 437 = [12] and connections acheived= 10
# no. of available ind2s  126
# connected id 437  to id 75  who has 19 connections out of  [12]
# id 437 now has  11  contacts
# no. of available ind2s  126
# connected id 437  to id 34  who has 16 connections out of  [11]
# id 437 now has  12  contacts
#
# finding connections for id 438  of area 1  in area 2
# connections needed for id 438 = [29] and connections acheived= 29
#
# finding connections for id 439  of area 1  in area 2
# connections needed for id 439 = [15] and connections acheived= 11
# no. of available ind2s  126
# connected id 439  to id 364  who has 8 connections out of  [8]
# id 439 now has  12  contacts
# no. of available ind2s  126
# connected id 439  to id 361  who has 18 connections out of  [7]
# id 439 now has  13  contacts
# no. of available ind2s  126
# connected id 439  to id 290  who has 8 connections out of  [4]
# id 439 now has  14  contacts
# no. of available ind2s  126
# Rejecting this id 371
# id 439 now has  14  contacts
# no. of available ind2s  125
# connected id 439  to id 41  who has 15 connections out of  [10]
# id 439 now has  15  contacts
# finding connections for id 440  of area 1  in area 2
# connections needed for id 440 = [34] and connections acheived= 32
# no. of available ind2s  125
# connected id 440  to id 379  who has 15 connections out of  [9]
# id 440 now has  33  contacts
# no. of available ind2s  125
# connected id 440  to id 460  who has 16 connections out of  [8]
# id 440 now has  34  contacts
#
# finding connections for id 465  of area 1  in area 2
# connections needed for id 465 = [7] and connections acheived= 6
# no. of available ind2s  125
# connected id 465  to id 310  who has 13 connections out of  [9]
# id 465 now has  7  contacts
#
# finding connections for id 466  of area 1  in area 2
# connections needed for id 466 = [6] and connections acheived= 5
# no. of available ind2s  125
# Rejecting this id 84
# id 466 now has  5  contacts
# no. of available ind2s  124
# connected id 466  to id 80  who has 17 connections out of  [15]
# id 466 now has  6  contacts
#
# finding connections for id 467  of area 1  in area 2
# connections needed for id 467 = [12] and connections acheived= 11
# no. of available ind2s  124
# connected id 467  to id 31  who has 17 connections out of  [10]
# id 467 now has  12  contacts
#
# finding connections for id 468  of area 1  in area 2
# connections needed for id 468 = [11] and connections acheived= 6
# no. of available ind2s  124
# connected id 468  to id 106  who has 14 connections out of  [8]
# id 468 now has  7  contacts
# no. of available ind2s  124
# connected id 468  to id 32  who has 10 connections out of  [10]
# id 468 now has  8  contacts
# no. of available ind2s  124
# connected id 468  to id 380  who has 16 connections out of  [12]
# id 468 now has  9  contacts
# no. of available ind2s  124
# connected id 468  to id 168  who has 11 connections out of  [8]
# id 468 now has  10  contacts
# no. of available ind2s  124
# Rejecting this id 108
# id 468 now has  10  contacts
# no. of available ind2s  123
# connected id 468  to id 189  who has 7 connections out of  [7]
# id 468 now has  11  contacts

# %%
obs_contact_within_hh = []
obs_contact_matrix_area = []

for ind in list(graph.nodes):
    contacts = list(graph.adj[ind])
    
    # first column is the area of the individual
    # creating an empty row for number of contacts in each area for ind
    contact_within_hh_row = [0]*2
    contact_within_hh_row[0] = ind.get_type_of_hh()
    count_within_hh = 0
    
    contact_area_row = [0] * (len(type_of_hh_array) + 1)    
    contact_area_row[0] = ind.get_type_of_hh()

    for contact in contacts:
        # if contact is in the same hh, increase count_within_hh by 1
        if ind.get_hh() == contact.get_hh():
            count_within_hh = count_within_hh + 1
            
        # otherwise increase the column about the area of the contact
        else:
            area_of_contact = contact.get_type_of_hh()
            # area of the contact is column number + 1 (indexing starts from 0)
            contact_area_row[area_of_contact + 1] = contact_area_row[area_of_contact + 1] + 1
        
        contact_within_hh_row[1] = count_within_hh
        
    obs_contact_within_hh.append(contact_within_hh_row)
    obs_contact_matrix_area.append(contact_area_row)

# %%
import pandas as pd
x = pd.DataFrame(obs_contact_matrix_area)
x.columns = ["", "0", "1", "2"]
print(x.groupby('')[['0', '1', '2']].mean())

input_contact_matrix_area = pd.DataFrame(mean_n_contacts_outside_hh)
print(input_contact_matrix_area)
# Out:
#           0         1         2
#
# 0  3.037838  3.956757  2.005405
# 1  5.856000  2.672000  2.016000
# 2  2.156977  1.465116  2.941860
#    0  1  2
# 0  3  4  2
# 1  2  3  2
# 2  2  2  3

# %%
cm1 = pd.DataFrame(obs_contact_within_hh)
cm1.columns = ["", 'within_hh']
print(cm1.groupby('')[['within_hh']].mean())

input_contact_within_hh = [x-1 for x in mean_hh_size_array]
input_contact_within_hh = pd.DataFrame(input_contact_within_hh)
input_contact_within_hh.columns = ['within_hh']
print(input_contact_within_hh)
# Out:
#    within_hh
#
# 0   4.897297
# 1   4.208000
# 2   4.686047
#    within_hh
# 0          4
# 1          4
# 2          4

# %%
# for area in range(len(type_of_hh_array)-1):  
#     # Outside area contacts will be done sequentially according to area
#     # making a list of individuals from the same area and those that have all their contact set - hence Do Not Disturb
#     list_ind_DND = []
#     if area > 0:
#         areas_DND = range(0, area + 1) # areas before this area and current (within) cannot be disturbed (connections)
#         for area_DND in areas_DND:
#             list_ind_DND =  list_ind_DND + list_hh_ind_input[2][area_DND]
    
#     # creating a list of individuals from outside the area and not from DND area    
#     list_inds_otherarea = list(set(list_hh_ind_input[1]) - set(list_ind_DND))

#     # looping through individuals    
#     for ind1 in list_hh_ind_input[2][area]:
#         ind1_degree_hh = ind1.get_hh_size() - 1 # this is fixed number for an individual
#         ind1_degree_hh_within_area = ind1_degree_hh + ind1.get_n_within_area_contacts() # this is fixed number for an individual
#         ind1_degree_hh_within_outside_area = ind1_degree_hh_within_area + ind1.get_n_outside_area_contacts() # this is fixed number for an individual

#         # don't run the following if the maximum possible connections for ind1 has been reached
#         while graph.degree[ind1] < ind1_degree_hh_within_outside_area:
#             # drawing a potential contact from outside the area
#             ind2  = random.sample(list_inds_otherarea, 1)[0]
#             # checking how many contacts this person can have (in hh and within area)
#             ind2_degree_hh = ind2.get_hh_size() - 1
#             ind2_degree_hh_within_area = ind2_degree_hh + ind2.get_n_within_area_contacts()
#             ind2_degree_hh_within_outside_area = ind2_degree_hh_within_area + ind2.get_n_outside_area_contacts() # this is fixed number for an individual
            
#             if graph.degree[ind2] == ind2_degree_hh_within_outside_area:
#                 list_inds_otherarea = list(set(list_inds_otherarea) - set([ind2]))
#             # check if this person is NOT already connected, or has not reached maximum possible connections setup
#             if (ind2 not in graph[ind1]) & (graph.degree[ind2] < ind2_degree_hh_within_outside_area):
#                 graph.add_edge(ind1, ind2)

# %%
# import networkx as nx
# import matplotlib as plt

# # creating connections between members of the same household
# # initialising graph
# graph = nx.Graph()

# for hh in range(n_hh):
#     inds_temp = list_hh_ind_input[0][hh].get_individuals()
#     graph.add_nodes_from(inds_temp)
#     graph.add_edges_from(itertools.combinations(inds_temp, 2))
    

# # list(graph.edges)
# # graph.degree[ind]

# # ADD THIS TO CREATING INDIVIDUALS FUNCTION
# # Adding attributes about how many contacts will people have within and outside their area
# for ind in list_hh_ind_input[1]:
#     area_temp = ind.get_type_of_hh()
#     # ADD POISSON DRAW HERE
#     temp_within_area_contacts = mean_n_contacts_within_area[area_temp] 
#     ind.add_n_within_area_contacts(temp_within_area_contacts)
#     # ADD POISSON DRAW HERE
#     temp_outside_area_contacts = mean_n_contacts_outside_area[area_temp] 
#     ind.add_n_outside_area_contacts(temp_outside_area_contacts)    

# # creating connections between members of the same area 
# # (this can take very long or run into problems with small sample sizes)   
# for area in range(len(type_of_hh_array)):
#     for ind1 in list_hh_ind_input[2][area]:   
#         # choosing ind1 from the list of individuals in a given area
#         ind1_degree_hh = ind1.get_hh_size() - 1 # this is fixed number for an individual
#         ind1_degree_hh_within_area = ind1_degree_hh + ind1.get_n_within_area_contacts() # this is fixed number for an individual

#         # don't run the following if the maximum possible connections for ind1 has been reached
#         while graph.degree[ind1] < ind1_degree_hh_within_area:    
#             # drawing a potential contact from within the area
#             ind2  = random.sample(list_hh_ind_input[2][area], 1)[0]
#             # checking how many contacts this person can have (in hh and within area)
#             ind2_degree_hh = ind2.get_hh_size() - 1
#             ind2_degree_hh_within_area = ind2_degree_hh + ind2.get_n_within_area_contacts()
#             # check if this person is NOT from same hh, or already connected, or has not reached maximum possible connections setup
#             if (ind2.get_hh() != ind1.get_hh()) & (ind2 not in graph[ind1]) & (graph.degree[ind2] < ind2_degree_hh_within_area):
#                 graph.add_edge(ind1, ind2)


            
# for area in range(len(type_of_hh_array)-1):  
#     # Outside area contacts will be done sequentially according to area
#     # making a list of individuals from the same area and those that have all their contact set - hence Do Not Disturb
#     list_ind_DND = []
#     if area > 0:
#         areas_DND = range(0, area + 1) # areas before this area and current (within) cannot be disturbed (connections)
#         for area_DND in areas_DND:
#             list_ind_DND =  list_ind_DND + list_hh_ind_input[2][area_DND]

#     # looping through individuals    
#     for ind1 in list_hh_ind_input[2][area]:
#         ind1_degree_hh = ind1.get_hh_size() - 1 # this is fixed number for an individual
#         ind1_degree_hh_within_area = ind1_degree_hh + ind1.get_n_within_area_contacts() # this is fixed number for an individual
#         ind1_degree_hh_within_outside_area = ind1_degree_hh_within_area + ind1.get_n_outside_area_contacts() # this is fixed number for an individual
#     #     print("ind" , ind1.get_ID(), "can have hh contacts = ", ind1_degree_hh)
#     #     print("ind" , ind1.get_ID(), "can have hh+within contacts = ", ind1_degree_hh_within_area)
#     #     print("ind" , ind1.get_ID(), "can have MAX contacts = ", ind1_degree_hh_within_outside_area)

#         # don't run the following if the maximum possible connections for ind1 has been reached
#         while graph.degree[ind1] < ind1_degree_hh_within_outside_area:
#             # drawing a potential contact from outside the area
#             list_inds_otherarea = list(set(list_hh_ind_input[1]) - set(list_ind_DND))
#             print(len(list_inds_otherarea))
#             ind2  = random.sample(list_inds_otherarea, 1)[0]
#             # checking how many contacts this person can have (in hh and within area)
#             ind2_degree_hh = ind2.get_hh_size() - 1
#             ind2_degree_hh_within_area = ind2_degree_hh + ind2.get_n_within_area_contacts()
#             ind2_degree_hh_within_outside_area = ind2_degree_hh_within_area + ind2.get_n_outside_area_contacts() # this is fixed number for an individual
#             # check if this person is NOT already connected, or has not reached maximum possible connections setup
#             if (ind2 not in graph[ind1]) & (graph.degree[ind2] < ind2_degree_hh_within_outside_area):
#                 graph.add_edge(ind1, ind2)

# %%
for i in list_hh_ind_input[2][0]:
    print(graph.degree[i])

# %%
# calculating total number of individuals created
n_ind_input = len(list_hh_ind_input[1])

# creating the initial adjacency list for this population
graph = create_adjacency_list(list_hh_ind_input = list_hh_ind_input, n_hh_input = n_hh, 
                                    n_ind_input = n_ind_input, \
                                    type_of_hh_array_input = type_of_hh_array, \
                                    mean_n_contacts_within_area_input = mean_n_contacts_within_area, \
                                    mean_n_contacts_outside_area_input = mean_n_contacts_outside_area)

# %%
len(list_hh_ind_input[2][0])

# %%
for i in range(len(list_hh_ind_input[2])):
    print(i)

# %%
for area_list in list_hh_ind_input[2]:
    for i in area_list:
        print("HELLO")
        print(i)

# %%
# running the simulations and the output is saved in csv files
sim(n_iter_input = n_iter, n_hh_input = n_hh, type_of_hh_array_input = type_of_hh_array, \
    prob_type_of_hh_array_input = prob_type_of_hh_array, mean_hh_size_array_input = mean_hh_size_array, \
    initial_prob_I_array_input = initial_prob_I_array, \
    mean_n_contacts_within_area_input = mean_n_contacts_within_area, \
    mean_n_contacts_outside_area_input = mean_n_contacts_outside_area, \
    t_max_input = t_max, max_recovery_t_input = max_recovery_t, p_t_input = p_t)

# %%
# importing outputs
import pandas as pd

dat = pd.read_csv('sim.csv')

# %%
# ploting S, I, R dynamics over time
import matplotlib.pyplot as plt

for i in range(1,n_iter+1): 
    dat_temp = dat.loc[dat['iter '] == i]
    
    # x axis values
    x = dat_temp[['time']]
    # corresponding y axis values
    S = dat_temp[['S']]
    I = dat_temp[['I']]
    R = dat_temp[['R']]

    # plotting the points
    plt.plot(x, S, 'y', label = "Susceptibles")
    plt.plot(x, I, 'r', label = "Infected")
    plt.plot(x, R, 'g', label = "Recovered")


    # naming the x axis
    plt.xlabel('Time')
    # naming the y axis
    plt.ylabel('y - axis')

# giving a title to my graph
plt.title('Number of individuals in states over time')
# show a legend on the plot
plt.legend(['Susceptible','Infected','Recovered'])
# function to show the plot
plt.show()

# %%
import pandas as pd

colnames = ['infector_ID', 'infector_type_of_hh', 'infectee_ID', 'infectee_type_of_hh', 'time', 'iter']
df = pd.read_csv('test.csv', names = colnames)
df = df.iloc[1: , :] # dropping first row (these are column headings now)
df = df.loc[df['iter'] == '1']

# %%
import networkx as nx
import matplotlib as plt

# fig, ax = plt.subplots(figsize=(15, 8))
# initialising graph
I = nx.Graph()

# creating edge list (reading it from the output)
edge_list = list(df[['infector_ID', 'infectee_ID']].apply(tuple, axis=1))
I.add_edges_from(edge_list)

df1 = df[['infector_ID', 'infector_type_of_hh']]
df1.columns = ['node', 'type_of_hh']
df2 = df[['infectee_ID', 'infectee_type_of_hh']]
df2.columns = ['node', 'type_of_hh']

frames = [df1, df2]

df3 = pd.concat(frames)
df3 = df3.drop_duplicates()

car = df3

# Make types into categories
car = car.set_index('node')

car['type_of_hh'] = pd.Categorical(car['type_of_hh'])

 
# Specify colors
cmap = plt.colors.ListedColormap(['C0', 'darkorange', 'green'])

# drawing network
nx.draw(I, with_labels=False, node_color=car['type_of_hh'].cat.codes, cmap = cmap)

# %%
# printing output of contacts 
list_ind = []
list_type_of_hh = []
list_hh_size = []
list_n_same_hh = []
list_n_same_area = []
list_n_outside_area = []
list_n_total = []

for i in range(n_ind_input):
    ind_temp = list(graph.m_adj_list.keys())[i].get_ID()
    list_ind.append(ind_temp)
    
    type_of_hh_temp = list(graph.m_adj_list.keys())[i].get_type_of_hh()
    list_type_of_hh.append(type_of_hh_temp) 
    
    hh_size_temp = int(list(graph.m_adj_list.keys())[i].get_hh_size())
    list_hh_size.append(hh_size_temp)
       
    n_same_hh_temp = len(list(filter(lambda x: x[1] == "same_hh", graph.m_adj_list[list(graph.m_adj_list.keys())[i]])))
    list_n_same_hh.append(n_same_hh_temp)
    
    n_same_area_temp = len(list(filter(lambda x: x[1] == "same_area", graph.m_adj_list[list(graph.m_adj_list.keys())[i]])))
    list_n_same_area.append(n_same_area_temp)
    
    n_outside_area_temp = len(list(filter(lambda x: x[1] == "outside_area", graph.m_adj_list[list(graph.m_adj_list.keys())[i]])))
    list_n_outside_area.append(n_outside_area_temp)
    
    n_total_temp = len(graph.m_adj_list[list(graph.m_adj_list.keys())[i]])
    list_n_total.append(n_total_temp)

    
contact_list = [list_ind, list_type_of_hh, list_hh_size, list_n_same_hh, list_n_same_area, list_n_outside_area, list_n_total]


# Convert output to a dataframe
import pandas as pd

contact_list_df = []
contact_list_df = pd.DataFrame(contact_list).transpose()
contact_list_df.rename(columns={0:"ID", 1: "type_of_hh", 2:"hh_size", 3:"contacts_within_hh", 4:"contacts_within_area", 5:"contacts_outside_area", 6: "contacts_total"}, inplace = True)

pd.set_option("display.max_rows", None, "display.max_columns", None)

display(contact_list_df)

# %%
from matplotlib import pyplot as plt

groups = contact_list_df.groupby("type_of_hh")
for name, group in groups:
    plt.hist(group["hh_size"], label=name, alpha = 0.5)
    plt.xlabel('Household size')
    plt.ylabel('Frequency')
plt.legend()
